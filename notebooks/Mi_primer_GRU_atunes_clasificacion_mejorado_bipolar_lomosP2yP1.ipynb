# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM,Bidirectional,GRU
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing import sequence
import datetime
import io
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

import sys
import os
# Obtener la ruta del directorio actual
os.chdir('/home/rgadea/experimentos_software_2024')
current_dir = os.getcwd()
print(current_dir)

# Construir la ruta relativa al directorio que quieres agregar
relative_dir = os.path.join(current_dir, 'mis_pkgs/')

# Agregar la ruta relativa al sys.path
sys.path.insert(0, relative_dir)

from MIOPATIA_db import DB_management as db
# Out:
# 2024-05-12 07:08:42.221795: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-12 07:08:42.221854: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-12 07:08:42.224744: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-12 07:08:42.238326: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-12 07:08:43.045913: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/rgadea/experimentos_software_2024

# %% [markdown]
# Voy a quedarme con los 50 atunes P1 para obtener conjunto de training y validacion

# %%
# !pwd
# Out:
# /home/rgadea/experimentos_software_2024

# %%
filename = "lomosP1_20240430_clasificado_experto_ampliado_the_best7.hdf"
with pd.HDFStore(filename,complib="zlib",complevel=4) as hdf_db:
    pre_p_e1  = hdf_db.get('data/pollos_estado')
    pre_p_e1 = pre_p_e1.loc[pre_p_e1['Pollo'] != 0]
    # p_e =pre_p_e1.drop_duplicates(subset = ['Pollo', 'Medida'],  keep = 'last').reset_index(drop = True)
    t    = hdf_db.get('data/tabla')
    X_train=np.zeros((pre_p_e1.shape[0],220,8))
    y_train=np.zeros((pre_p_e1.shape[0],1))
    x=0
    for index, row in pre_p_e1.iterrows():   # El primer registro no se toma en cuenta porque es basura
        Primero = int(row['Primero'])
        Ultimo  = int(row['Ultimo'])
        estado  = int(row['Estado'])
        # print(Primero)
        # print(Ultimo)
        # print(estado)
        if estado == 0 or estado== 1:
            target = 1
        else:
            target = 0
        pepito=np.array(t.iloc[Primero:Ultimo+1])
        # #print(pepito.shape)
        X_train[x]=pepito[:,3:11]
        #print(X_train[x][0:4,:])       
        y_train[x]=target
        x=x+1


print(X_train.shape)
print(y_train.shape)
#print(X_train[0:4,:,:])
# Out:
# (6600, 220, 8)
# (6600, 1)

# %%
#print(X_train[1][0:4][:])

# %%
#print(y_train[1:20])

# %% [markdown]
# Aqui filtrariamos si hay filas que no nos interesan. En este caso dejo pasar todos los casos

# %%
# print(p_e)
# # X_train_filtrado = X_train[2:][:,:]
# # y_train_filtrado = y_train[2:]
X_train_filtrado = X_train
y_train_filtrado = y_train

# print(X_train_filtrado.shape)
# print(y_train_filtrado.shape)
# print(X_train_filtrado[0][:,:])

# %% [markdown]
# Vamos a normalizar o escalar los datos

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_2d = X_train_filtrado.reshape(-1, X_train_filtrado.shape[-1])
normalized_data_2d = scaler.fit_transform(data_2d)
X_train_Normalizado=normalized_data_2d.reshape(X_train_filtrado.shape)
y_train_Normalizado=y_train_filtrado # los valores ya estaban normalizados
print(X_train_Normalizado[0])
# Out:
# [[5.59059849e-04 6.02334232e-01 2.09243895e-01 ... 3.97666103e-01
#   5.59148408e-04 8.98444367e-01]
#  [5.32692283e-04 6.01851048e-01 2.10280898e-01 ... 3.98149286e-01
#   5.32776684e-04 8.98444937e-01]
#  [5.23422176e-04 6.02312810e-01 2.08059305e-01 ... 3.97687525e-01
#   5.23505162e-04 8.98445730e-01]
#  ...
#  [6.90117158e-07 4.10655386e-01 1.65373568e-01 ... 5.89344843e-01
#   6.90201187e-07 8.98463166e-01]
#  [3.49024769e-07 4.14711733e-01 1.65342858e-01 ... 5.85288497e-01
#   3.49145000e-07 8.98463350e-01]
#  [0.00000000e+00 4.19288217e-01 1.65312668e-01 ... 5.80712016e-01
#   1.56981087e-10 8.98463540e-01]]

# %%
filename = "lomosP2_20240430_clasificado_experto.hdf"
with pd.HDFStore(filename,complib="zlib",complevel=4) as hdf_db:
    pre_p_e1  = hdf_db.get('data/pollos_estado')
    pre_p_e1 = pre_p_e1.loc[pre_p_e1['Pollo'] != 0]
    pre_p_e1 =pre_p_e1.drop_duplicates(subset = ['Pollo', 'Medida'],  keep = 'last').reset_index(drop = True)
    t    = hdf_db.get('data/tabla')
    X_test=np.zeros((pre_p_e1.shape[0],220,8))
    y_test=np.zeros((pre_p_e1.shape[0],1))
    x=0
    for index, row in pre_p_e1.iterrows():   # El primer registro no se toma en cuenta porque es basura
        Primero = int(row['Primero'])
        Ultimo  = int(row['Ultimo'])
        estado  = int(row['Estado'])
        #print(Primero)
        #print(Ultimo)
        #print(estado)
        if estado == 0 or estado== 1:
           target = 1
        else:
           target = 0
        #target=estado
        pepito=np.array(t.iloc[Primero:Ultimo+1])
        # #print(pepito.shape)
        X_test[x]=pepito[:,3:11]
        #print(X_train[x][0:4,:])       
        y_test[x]=target
        #y_test_to_categorical = to_categorical(y_test)
        x=x+1


# print(X_train.shape)
# print(y_train_to_categorical.shape)
# #print(X_train[0:4,:,:])
# #print(X_train[1][0:4][:])
# print(y_train[1:20])
# print(y_train_to_categorical[1:20])
# # #Aqui filtrariamos si hay filas que no nos interesan. En este caso dejo pasar todos los casos
# print(p_e)
# # X_train_filtrado = X_train[2:][:,:]
# # y_train_filtrado = y_train[2:]
X_test_filtrado = X_test
#y_train_filtrado = y_train
y_test_filtrado = y_test

print(X_test_filtrado.shape)
print(y_test_filtrado.shape)
# print(X_train_filtrado[0][:,:])
# # # Vamos a normalizar o escalar los datos

#data_2d_test = X_total.reshape(-1, X_total.shape[-1])
data_2d_test = X_test_filtrado.reshape(-1, X_test_filtrado.shape[-1])
normalized_data_2d_test = scaler.transform(data_2d_test)


X_test_def=normalized_data_2d_test.reshape(X_test_filtrado.shape) 
# la alternativa es normalizar con el total
# X_test_def=normalized_data_2d_test.reshape(X_test_filtrado.shape) 

y_test_def=y_test_filtrado # los valores ya estaban normalizados
print(X_test_def[0])
# Out:
# (200, 220, 8)
# (200, 1)
# [[9.22817842e-05 5.87443890e-01 5.89112793e-01 ... 4.12556437e-01
#   9.22970969e-05 8.98459889e-01]
#  [8.47509972e-05 5.75508842e-01 7.43321507e-01 ... 4.24491478e-01
#   8.47648642e-05 8.98458459e-01]
#  [8.33032685e-05 5.76993951e-01 7.08974820e-01 ... 4.23006370e-01
#   8.33169571e-05 8.98458817e-01]
#  ...
#  [6.94572558e-06 4.09972734e-01 1.64852139e-01 ... 5.90027494e-01
#   6.94591964e-06 8.98460829e-01]
#  [6.39026543e-06 4.07783620e-01 1.64853563e-01 ... 5.92216607e-01
#   6.39040826e-06 8.98460981e-01]
#  [5.82518692e-06 4.05732518e-01 1.64856062e-01 ... 5.94267707e-01
#   5.82528366e-06 8.98461145e-01]]

# %% [markdown]
# Vamos a hacer los conjuntos de entrenamiento validacion y test

# %%
# Divide el dataset en entrenamiento y temporal (test+validación)
# X_temp, X_test_def, y_temp, y_test_def = train_test_split(X_train_Normalizado, y_train_Normalizado, test_size=0.2, stratify=y_train_Normalizado, random_state=42)

# Divide el dataset temporal en validación y test
X_train_def, X_val_def, y_train_def, y_val_def = train_test_split(X_train_Normalizado, y_train_Normalizado, test_size=0.25, stratify=y_train_Normalizado, random_state=42)

# Ahora, X_train, X_val y X_test contienen los datos de entrada para los conjuntos de entrenamiento, validación y prueba, respectivamente.
# y_train, y_val y y_test contienen las clases correspondientes.

# %%
print(X_train_def.shape)
print(X_val_def.shape)
print(X_test_def.shape)
print(y_train_def.shape)
print(y_val_def.shape)
print(y_test_def.shape)
# Out:
# (4950, 220, 8)
# (1650, 220, 8)
# (200, 220, 8)
# (4950, 1)
# (1650, 1)
# (200, 1)

# %%
# %load_ext tensorboard

# %tensorboard --logdir logs
#log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
#tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
def plot_to_image(figure):
    """
    Converts the matplotlib plot specified by 'figure' to a PNG image and
    returns it. The supplied figure is closed and inaccessible after this call.
    """
    
    buf = io.BytesIO()
    
    # Use plt.savefig to save the plot to a PNG in memory.
    plt.savefig(buf, format='png')
    
    # Closing the figure prevents it from being displayed directly inside
    # the notebook.
    plt.close(figure)
    buf.seek(0)
    
    # Use tf.image.decode_png to convert the PNG buffer
    # to a TF image. Make sure you use 4 channels.
    image = tf.image.decode_png(buf.getvalue(), channels=4)
    
    # Use tf.expand_dims to add the batch dimension
    image = tf.expand_dims(image, 0)
    
    return image

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Returns a matplotlib figure containing the plotted confusion matrix.
    
    Args:
       cm (array, shape = [n, n]): a confusion matrix of integer classes
       class_names (array, shape = [n]): String names of the integer classes
    """
    
    figure = plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)
    
    # Normalize the confusion matrix.
    cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)
    
    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    threshold = 0.5
    
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "red" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return figure

# %%
algoritmo='RMSprop'
supermax=8*4
lossfunction='binary_crossentropy'
factor_aprendizaje=0.001
dimension_LSTM=50
dimension_dense=50
model = Sequential()
model.add(GRU(dimension_LSTM, return_sequences=True,input_shape=(220, 8)))
#model.add(Bidirectional(LSTM(50, return_sequences=True)))
#model.add(Bidirectional(LSTM(50, return_sequences=True)))
#model.add(Bidirectional(LSTM(50, return_sequences=False)))
model.add(Dense(dimension_dense, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss=lossfunction, optimizer=algoritmo, metrics=['accuracy'])
model.optimizer.lr=(factor_aprendizaje)
print(model.summary())

experimento="LOMOS_P1_P2_GRU3_return_sequences_{}_densebipolar_{}_loss_{}_lr_{}_algoritmo_{}".format(dimension_LSTM,dimension_dense,lossfunction,factor_aprendizaje,algoritmo)
logdir="./logs/defs/{}_{}".format(experimento,datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback=tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1)
file_writer_cm = tf.summary.create_file_writer(logdir + '/cm')
# Out:
# 2024-05-12 07:08:49.497310: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2024-05-12 07:08:49.497442: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:129] retrieving CUDA diagnostic information for host: nodofpga-2024.novalocal
# 2024-05-12 07:08:49.497468: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:136] hostname: nodofpga-2024.novalocal
# 2024-05-12 07:08:49.497852: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:159] libcuda reported version is: 535.161.7
# 2024-05-12 07:08:49.498003: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] kernel reported version is: 535.161.7
# 2024-05-12 07:08:49.498027: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:241] kernel version seems to match DSO: 535.161.7
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 220, 50)           9000
#
#  dense (Dense)               (None, 220, 50)           2550
#
#  dense_1 (Dense)             (None, 220, 1)            51
#
# =================================================================
# Total params: 11601 (45.32 KB)
# Trainable params: 11601 (45.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
class_names=["Normal","Anormal"]

# %%
def log_confusion_matrix(epoch, logs):
    
    # Use the model to predict the values from the test_images.
    y_pred = model.predict(X_test_def)
    y_pred2=np.round(y_pred[:,-1]).astype(int)
    #y_pred2=np.where(y_pred>0,1,0)
    #y_pred2=y_pred2[:,-1]
    y_test_def2=y_test_def  
    #y_test_def2=np.where(y_test_def>0,1,0)
    cm=confusion_matrix(y_test_def2, y_pred2)
    # disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    figura = plot_confusion_matrix(cm, class_names=class_names)
    cm_image = plot_to_image(figura)
    
    # Log the confusion matrix as an image summary.
    with file_writer_cm.as_default():
        tf.summary.image("Confusion Matrix", cm_image, step=epoch)

# %%
cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

# %%
early_stop=tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=500, verbose=2, mode='auto', baseline=None, restore_best_weights=True)
model.fit(X_train_Normalizado, y_train_Normalizado, epochs=2000, batch_size=20, callbacks=[tensorboard_callback, cm_callback, early_stop], validation_data=(X_val_def, y_val_def))
# Final evaluation of the model
# Out:
# Epoch 1/2000
# 7/7 [==============================] - 1s 25ms/step- loss: 0.6885 - accuracy:
# 330/330 [==============================] - 26s 73ms/step - loss: 0.6885 - accuracy: 0.5562 - val_loss: 0.6859 - val_accuracy: 0.5600
# Epoch 2/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6875 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6875 - accuracy: 0.5590 - val_loss: 0.6860 - val_accuracy: 0.5600
# Epoch 3/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6868 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6868 - accuracy: 0.5585 - val_loss: 0.6861 - val_accuracy: 0.5600
# Epoch 4/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6869 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6869 - accuracy: 0.5600 - val_loss: 0.6860 - val_accuracy: 0.5600
# Epoch 5/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6868 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6868 - accuracy: 0.5600 - val_loss: 0.6866 - val_accuracy: 0.5600
# Epoch 6/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6867 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.6867 - accuracy: 0.5600 - val_loss: 0.6872 - val_accuracy: 0.5600
# Epoch 7/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6866 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6866 - accuracy: 0.5600 - val_loss: 0.6866 - val_accuracy: 0.5600
# Epoch 8/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6865 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6865 - accuracy: 0.5600 - val_loss: 0.6871 - val_accuracy: 0.5600
# Epoch 9/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6866 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6866 - accuracy: 0.5600 - val_loss: 0.6859 - val_accuracy: 0.5600
# Epoch 10/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6866 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6866 - accuracy: 0.5600 - val_loss: 0.6859 - val_accuracy: 0.5600
# Epoch 11/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6862 - accuracy: 0.5600 - val_loss: 0.6874 - val_accuracy: 0.5602
# Epoch 12/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6864 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6864 - accuracy: 0.5600 - val_loss: 0.6866 - val_accuracy: 0.5600
# Epoch 13/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.6860 - val_accuracy: 0.5601
# Epoch 14/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6865 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6865 - accuracy: 0.5600 - val_loss: 0.6861 - val_accuracy: 0.5600
# Epoch 15/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6861 - accuracy: 0.5599 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 16/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.6859 - val_accuracy: 0.5600
# Epoch 17/2000
# 7/7 [==============================] - 0s 29ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6871 - val_accuracy: 0.5601
# Epoch 18/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6865 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6865 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 19/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6864 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6864 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 20/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.6861 - val_accuracy: 0.5601
# Epoch 21/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6864 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6864 - accuracy: 0.5601 - val_loss: 0.6861 - val_accuracy: 0.5602
# Epoch 22/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 23/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6862 - val_accuracy: 0.5602
# Epoch 24/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6864 - val_accuracy: 0.5601
# Epoch 25/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6861 - val_accuracy: 0.5601
# Epoch 26/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6860 - val_accuracy: 0.5601
# Epoch 27/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6861 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 28/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5602
# Epoch 29/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 30/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5602
# Epoch 31/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6861 - val_accuracy: 0.5601
# Epoch 32/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6861 - accuracy: 0.5600 - val_loss: 0.6862 - val_accuracy: 0.5602
# Epoch 33/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 34/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.6862 - accuracy: 0.5602 - val_loss: 0.6859 - val_accuracy: 0.5602
# Epoch 35/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.6862 - accuracy: 0.5602 - val_loss: 0.6865 - val_accuracy: 0.5601
# Epoch 36/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6864 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.6864 - accuracy: 0.5601 - val_loss: 0.6858 - val_accuracy: 0.5601
# Epoch 37/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6863 - accuracy
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 38/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 39/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6862 - accuracy: 0.5600 - val_loss: 0.6861 - val_accuracy: 0.5602
# Epoch 40/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.6858 - val_accuracy: 0.5601
# Epoch 41/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6858 - val_accuracy: 0.5601
# Epoch 42/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6858 - val_accuracy: 0.5601
# Epoch 43/2000
# 7/7 [==============================] - 0s 32ms/step- loss: 0.6861 - accuracy
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6861 - accuracy: 0.5602 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 44/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6858 - val_accuracy: 0.5601
# Epoch 45/2000
# 7/7 [==============================] - 0s 29ms/step- loss: 0.6863 - accuracy
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.6861 - val_accuracy: 0.5601
# Epoch 46/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.6860 - val_accuracy: 0.5601
# Epoch 47/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.6858 - val_accuracy: 0.5602
# Epoch 48/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6860 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6860 - accuracy: 0.5602 - val_loss: 0.6862 - val_accuracy: 0.5602
# Epoch 49/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 50/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6861 - accuracy: 0.5600 - val_loss: 0.6859 - val_accuracy: 0.5601
# Epoch 51/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6861 - val_accuracy: 0.5602
# Epoch 52/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6867 - val_accuracy: 0.5602
# Epoch 53/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6862 - val_accuracy: 0.5602
# Epoch 54/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6861 - accuracy: 0.5600 - val_loss: 0.6860 - val_accuracy: 0.5601
# Epoch 55/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6858 - accuracy:
# 330/330 [==============================] - 25s 75ms/step - loss: 0.6858 - accuracy: 0.5601 - val_loss: 0.6868 - val_accuracy: 0.5602
# Epoch 56/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6862 - accuracy: 0.5602 - val_loss: 0.6858 - val_accuracy: 0.5601
# Epoch 57/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6862 - accuracy: 0.5600 - val_loss: 0.6858 - val_accuracy: 0.5602
# Epoch 58/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6861 - accuracy: 0.5600 - val_loss: 0.6859 - val_accuracy: 0.5602
# Epoch 59/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6861 - accuracy: 0.5601 - val_loss: 0.6866 - val_accuracy: 0.5602
# Epoch 60/2000
# 7/7 [==============================] - 0s 29ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.6858 - val_accuracy: 0.5602
# Epoch 61/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6861 - val_accuracy: 0.5602
# Epoch 62/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6858 - val_accuracy: 0.5602
# Epoch 63/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6862 - accuracy: 0.5602 - val_loss: 0.6858 - val_accuracy: 0.5601
# Epoch 64/2000
# 7/7 [==============================] - 0s 31ms/step- loss: 0.6860 - accuracy
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6860 - accuracy: 0.5603 - val_loss: 0.6862 - val_accuracy: 0.5601
# Epoch 65/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6860 - accuracy:
# 330/330 [==============================] - 25s 74ms/step - loss: 0.6860 - accuracy: 0.5600 - val_loss: 0.6858 - val_accuracy: 0.5602
# Epoch 66/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6861 - accuracy: 0.5602 - val_loss: 0.6861 - val_accuracy: 0.5603
# Epoch 67/2000
# 7/7 [==============================] - 0s 29ms/step- loss: 0.6861 - accuracy
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6861 - accuracy: 0.5601 - val_loss: 0.6858 - val_accuracy: 0.5603
# Epoch 68/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6861 - accuracy: 0.5602 - val_loss: 0.6858 - val_accuracy: 0.5603
# Epoch 69/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6862 - accuracy: 0.5601 - val_loss: 0.6858 - val_accuracy: 0.5603
# Epoch 70/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6861 - accuracy: 0.5603 - val_loss: 0.6858 - val_accuracy: 0.5604
# Epoch 71/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6862 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6862 - accuracy: 0.5603 - val_loss: 0.6858 - val_accuracy: 0.5603
# Epoch 72/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6861 - accuracy: 0.5604 - val_loss: 0.6857 - val_accuracy: 0.5603
# Epoch 73/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6861 - accuracy: 0.5603 - val_loss: 0.6859 - val_accuracy: 0.5603
# Epoch 74/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6861 - accuracy: 0.5604 - val_loss: 0.6857 - val_accuracy: 0.5604
# Epoch 75/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6860 - accuracy
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6860 - accuracy: 0.5603 - val_loss: 0.6858 - val_accuracy: 0.5604
# Epoch 76/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6860 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6860 - accuracy: 0.5603 - val_loss: 0.6864 - val_accuracy: 0.5601
# Epoch 77/2000
# 7/7 [==============================] - 0s 29ms/step- loss: 0.6859 - accuracy
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6859 - accuracy: 0.5602 - val_loss: 0.6858 - val_accuracy: 0.5604
# Epoch 78/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6861 - accuracy: 0.5602 - val_loss: 0.6856 - val_accuracy: 0.5606
# Epoch 79/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6861 - accuracy: 0.5605 - val_loss: 0.6858 - val_accuracy: 0.5603
# Epoch 80/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6860 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6860 - accuracy: 0.5605 - val_loss: 0.6856 - val_accuracy: 0.5606
# Epoch 81/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6859 - accuracy:
# 330/330 [==============================] - 24s 74ms/step - loss: 0.6859 - accuracy: 0.5605 - val_loss: 0.6881 - val_accuracy: 0.5603
# Epoch 82/2000
# 7/7 [==============================] - 0s 20ms/step- loss: 0.6863 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6863 - accuracy: 0.5605 - val_loss: 0.6856 - val_accuracy: 0.5604
# Epoch 83/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6860 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6860 - accuracy: 0.5604 - val_loss: 0.6855 - val_accuracy: 0.5606
# Epoch 84/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6860 - accuracy:
# 330/330 [==============================] - 24s 74ms/step - loss: 0.6860 - accuracy: 0.5605 - val_loss: 0.6856 - val_accuracy: 0.5606
# Epoch 85/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6859 - accuracy
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6859 - accuracy: 0.5605 - val_loss: 0.6858 - val_accuracy: 0.5606
# Epoch 86/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6860 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6860 - accuracy: 0.5603 - val_loss: 0.6854 - val_accuracy: 0.5606
# Epoch 87/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6859 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6859 - accuracy: 0.5608 - val_loss: 0.6856 - val_accuracy: 0.5606
# Epoch 88/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6858 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6858 - accuracy: 0.5608 - val_loss: 0.6858 - val_accuracy: 0.5612
# Epoch 89/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6858 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6858 - accuracy: 0.5616 - val_loss: 0.6852 - val_accuracy: 0.5607
# Epoch 90/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6857 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6857 - accuracy: 0.5609 - val_loss: 0.6852 - val_accuracy: 0.5613
# Epoch 91/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6857 - accuracy:
# 330/330 [==============================] - 25s 74ms/step - loss: 0.6857 - accuracy: 0.5611 - val_loss: 0.6852 - val_accuracy: 0.5614
# Epoch 92/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6855 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6855 - accuracy: 0.5612 - val_loss: 0.6862 - val_accuracy: 0.5619
# Epoch 93/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6856 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6856 - accuracy: 0.5613 - val_loss: 0.6856 - val_accuracy: 0.5616
# Epoch 94/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6858 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6858 - accuracy: 0.5618 - val_loss: 0.6850 - val_accuracy: 0.5622
# Epoch 95/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6853 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.6853 - accuracy: 0.5607 - val_loss: 0.6855 - val_accuracy: 0.5629
# Epoch 96/2000
# 7/7 [==============================] - 0s 30ms/step- loss: 0.6856 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6856 - accuracy: 0.5621 - val_loss: 0.6850 - val_accuracy: 0.5625
# Epoch 97/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6856 - accuracy:
# 330/330 [==============================] - 25s 75ms/step - loss: 0.6856 - accuracy: 0.5627 - val_loss: 0.6853 - val_accuracy: 0.5616
# Epoch 98/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6856 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6856 - accuracy: 0.5620 - val_loss: 0.6854 - val_accuracy: 0.5617
# Epoch 99/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6855 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6855 - accuracy: 0.5618 - val_loss: 0.6849 - val_accuracy: 0.5625
# Epoch 100/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6854 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6854 - accuracy: 0.5619 - val_loss: 0.6860 - val_accuracy: 0.5610
# Epoch 101/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6856 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6856 - accuracy: 0.5621 - val_loss: 0.6849 - val_accuracy: 0.5621
# Epoch 102/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6854 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6854 - accuracy: 0.5631 - val_loss: 0.6849 - val_accuracy: 0.5654
# Epoch 103/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6853 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6853 - accuracy: 0.5629 - val_loss: 0.6845 - val_accuracy: 0.5641
# Epoch 104/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6852 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6852 - accuracy: 0.5628 - val_loss: 0.6845 - val_accuracy: 0.5637
# Epoch 105/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6861 - accuracy: 0.5644 - val_loss: 0.6852 - val_accuracy: 0.5619
# Epoch 106/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6855 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6855 - accuracy: 0.5633 - val_loss: 0.6827 - val_accuracy: 0.5632
# Epoch 107/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6845 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6845 - accuracy: 0.5643 - val_loss: 0.6823 - val_accuracy: 0.5638
# Epoch 108/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6858 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6858 - accuracy: 0.5636 - val_loss: 0.6819 - val_accuracy: 0.5666
# Epoch 109/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6882 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6882 - accuracy: 0.5576 - val_loss: 0.6883 - val_accuracy: 0.5529
# Epoch 110/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6857 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6857 - accuracy: 0.5564 - val_loss: 0.6848 - val_accuracy: 0.5610
# Epoch 111/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6861 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.6861 - accuracy: 0.5587 - val_loss: 0.6847 - val_accuracy: 0.5609
# Epoch 112/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6856 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6856 - accuracy: 0.5615 - val_loss: 0.6726 - val_accuracy: 0.6124
# Epoch 113/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6865 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.6865 - accuracy: 0.5599 - val_loss: 0.6832 - val_accuracy: 0.5616
# Epoch 114/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6826 - accuracy
# 330/330 [==============================] - 22s 66ms/step - loss: 0.6826 - accuracy: 0.5752 - val_loss: 0.6792 - val_accuracy: 0.5701
# Epoch 115/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6807 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6807 - accuracy: 0.5801 - val_loss: 0.6937 - val_accuracy: 0.4605
# Epoch 116/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6813 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6813 - accuracy: 0.5754 - val_loss: 0.6734 - val_accuracy: 0.5867
# Epoch 117/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6872 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6872 - accuracy: 0.5620 - val_loss: 0.6754 - val_accuracy: 0.5913
# Epoch 118/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6837 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.6837 - accuracy: 0.5607 - val_loss: 0.6820 - val_accuracy: 0.5610
# Epoch 119/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6789 - accuracy
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6789 - accuracy: 0.5817 - val_loss: 0.6770 - val_accuracy: 0.5827
# Epoch 120/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6793 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6793 - accuracy: 0.5823 - val_loss: 0.6810 - val_accuracy: 0.5686
# Epoch 121/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6767 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6767 - accuracy: 0.5858 - val_loss: 0.6772 - val_accuracy: 0.5866
# Epoch 122/2000
# 7/7 [==============================] - 0s 20ms/step- loss: 0.6783 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6783 - accuracy: 0.5831 - val_loss: 0.6815 - val_accuracy: 0.5721
# Epoch 123/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6795 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6795 - accuracy: 0.5813 - val_loss: 0.6707 - val_accuracy: 0.5976
# Epoch 124/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6779 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6779 - accuracy: 0.5841 - val_loss: 0.6775 - val_accuracy: 0.5912
# Epoch 125/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6750 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6750 - accuracy: 0.5912 - val_loss: 0.6687 - val_accuracy: 0.6050
# Epoch 126/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6817 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6817 - accuracy: 0.5705 - val_loss: 0.6885 - val_accuracy: 0.5640
# Epoch 127/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6748 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6748 - accuracy: 0.5879 - val_loss: 0.6736 - val_accuracy: 0.5891
# Epoch 128/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6736 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6736 - accuracy: 0.5874 - val_loss: 0.6828 - val_accuracy: 0.5771
# Epoch 129/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6743 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6743 - accuracy: 0.5844 - val_loss: 0.6701 - val_accuracy: 0.5897
# Epoch 130/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6722 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6722 - accuracy: 0.5897 - val_loss: 0.6658 - val_accuracy: 0.5931
# Epoch 131/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6720 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6720 - accuracy: 0.5908 - val_loss: 0.6649 - val_accuracy: 0.5986
# Epoch 132/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6676 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6676 - accuracy: 0.5919 - val_loss: 0.6710 - val_accuracy: 0.5869
# Epoch 133/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6664 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6664 - accuracy: 0.5938 - val_loss: 0.6716 - val_accuracy: 0.5890
# Epoch 134/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6642 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6642 - accuracy: 0.5953 - val_loss: 0.6589 - val_accuracy: 0.5945
# Epoch 135/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6598 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6598 - accuracy: 0.5973 - val_loss: 0.6526 - val_accuracy: 0.6058
# Epoch 136/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6592 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.6592 - accuracy: 0.5983 - val_loss: 0.6762 - val_accuracy: 0.5796
# Epoch 137/2000
# 7/7 [==============================] - 0s 29ms/step- loss: 0.6608 - accuracy
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6609 - accuracy: 0.5962 - val_loss: 0.6610 - val_accuracy: 0.5930
# Epoch 138/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6590 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6590 - accuracy: 0.5982 - val_loss: 0.6552 - val_accuracy: 0.6006
# Epoch 139/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6550 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6550 - accuracy: 0.6020 - val_loss: 0.6490 - val_accuracy: 0.6040
# Epoch 140/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6548 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.6548 - accuracy: 0.6015 - val_loss: 0.6508 - val_accuracy: 0.6018
# Epoch 141/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6534 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6534 - accuracy: 0.6030 - val_loss: 0.6500 - val_accuracy: 0.6038
# Epoch 142/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6513 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6513 - accuracy: 0.6057 - val_loss: 0.6572 - val_accuracy: 0.5959
# Epoch 143/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6543 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6543 - accuracy: 0.6014 - val_loss: 0.6543 - val_accuracy: 0.5998
# Epoch 144/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6547 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6547 - accuracy: 0.6015 - val_loss: 0.6734 - val_accuracy: 0.5858
# Epoch 145/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6512 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6512 - accuracy: 0.6050 - val_loss: 0.6512 - val_accuracy: 0.6022
# Epoch 146/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6489 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6489 - accuracy: 0.6071 - val_loss: 0.6501 - val_accuracy: 0.6052
# Epoch 147/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6470 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6470 - accuracy: 0.6085 - val_loss: 0.6417 - val_accuracy: 0.6137
# Epoch 148/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6534 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6534 - accuracy: 0.6067 - val_loss: 0.6668 - val_accuracy: 0.5941
# Epoch 149/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6672 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.6672 - accuracy: 0.5886 - val_loss: 0.6662 - val_accuracy: 0.5906
# Epoch 150/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6609 - accuracy
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6609 - accuracy: 0.6065 - val_loss: 0.6466 - val_accuracy: 0.6119
# Epoch 151/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6529 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6529 - accuracy: 0.6086 - val_loss: 0.6395 - val_accuracy: 0.6251
# Epoch 152/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6617 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6617 - accuracy: 0.6031 - val_loss: 0.6439 - val_accuracy: 0.6257
# Epoch 153/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6537 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6537 - accuracy: 0.6144 - val_loss: 0.7010 - val_accuracy: 0.5980
# Epoch 154/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6721 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6721 - accuracy: 0.5953 - val_loss: 0.6795 - val_accuracy: 0.5843
# Epoch 155/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6610 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6610 - accuracy: 0.6031 - val_loss: 0.6497 - val_accuracy: 0.6095
# Epoch 156/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6492 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6492 - accuracy: 0.6130 - val_loss: 0.6410 - val_accuracy: 0.6229
# Epoch 157/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.6695 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6695 - accuracy: 0.6003 - val_loss: 0.6860 - val_accuracy: 0.5700
# Epoch 158/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6637 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6637 - accuracy: 0.6005 - val_loss: 0.6640 - val_accuracy: 0.6067
# Epoch 159/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6513 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6513 - accuracy: 0.6170 - val_loss: 0.6400 - val_accuracy: 0.6275
# Epoch 160/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6472 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6472 - accuracy: 0.6192 - val_loss: 0.6506 - val_accuracy: 0.6167
# Epoch 161/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6501 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6501 - accuracy: 0.6137 - val_loss: 0.6447 - val_accuracy: 0.6219
# Epoch 162/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6475 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6475 - accuracy: 0.6209 - val_loss: 0.6362 - val_accuracy: 0.6270
# Epoch 163/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6574 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6574 - accuracy: 0.6090 - val_loss: 0.6818 - val_accuracy: 0.5750
# Epoch 164/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6566 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6566 - accuracy: 0.6098 - val_loss: 0.6472 - val_accuracy: 0.6241
# Epoch 165/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6558 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6558 - accuracy: 0.6108 - val_loss: 0.6704 - val_accuracy: 0.5850
# Epoch 166/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6653 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.6653 - accuracy: 0.5979 - val_loss: 0.6599 - val_accuracy: 0.5965
# Epoch 167/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6548 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6548 - accuracy: 0.6120 - val_loss: 0.6663 - val_accuracy: 0.6004
# Epoch 168/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6515 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6515 - accuracy: 0.6112 - val_loss: 0.6496 - val_accuracy: 0.6170
# Epoch 169/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6369 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6369 - accuracy: 0.6172 - val_loss: 0.6259 - val_accuracy: 0.6338
# Epoch 170/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.6362 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.6362 - accuracy: 0.6266 - val_loss: 0.6491 - val_accuracy: 0.6061
# Epoch 171/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6340 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6340 - accuracy: 0.6231 - val_loss: 0.6284 - val_accuracy: 0.6374
# Epoch 172/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6373 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6373 - accuracy: 0.6205 - val_loss: 0.6421 - val_accuracy: 0.6209
# Epoch 173/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.6475 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6475 - accuracy: 0.6158 - val_loss: 0.6372 - val_accuracy: 0.6319
# Epoch 174/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6383 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6383 - accuracy: 0.6254 - val_loss: 0.6407 - val_accuracy: 0.5989
# Epoch 175/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6417 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6417 - accuracy: 0.6161 - val_loss: 0.6300 - val_accuracy: 0.6318
# Epoch 176/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6339 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6339 - accuracy: 0.6261 - val_loss: 0.6232 - val_accuracy: 0.6328
# Epoch 177/2000
# 7/7 [==============================] - 0s 29ms/step- loss: 0.6243 - accuracy
# 330/330 [==============================] - 24s 74ms/step - loss: 0.6243 - accuracy: 0.6350 - val_loss: 0.6219 - val_accuracy: 0.6514
# Epoch 178/2000
# 7/7 [==============================] - 0s 19ms/step- loss: 0.6250 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.6250 - accuracy: 0.6446 - val_loss: 0.6052 - val_accuracy: 0.6795
# Epoch 179/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6283 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6283 - accuracy: 0.6319 - val_loss: 0.6256 - val_accuracy: 0.6348
# Epoch 180/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6255 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6255 - accuracy: 0.6370 - val_loss: 0.6191 - val_accuracy: 0.6461
# Epoch 181/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6218 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6218 - accuracy: 0.6459 - val_loss: 0.6190 - val_accuracy: 0.6447
# Epoch 182/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6305 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6305 - accuracy: 0.6380 - val_loss: 0.6552 - val_accuracy: 0.6016
# Epoch 183/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6322 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.6322 - accuracy: 0.6405 - val_loss: 0.6133 - val_accuracy: 0.6579
# Epoch 184/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6299 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.6299 - accuracy: 0.6420 - val_loss: 0.6426 - val_accuracy: 0.6280
# Epoch 185/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6250 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6250 - accuracy: 0.6386 - val_loss: 0.6172 - val_accuracy: 0.6692
# Epoch 186/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6267 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6267 - accuracy: 0.6324 - val_loss: 0.6197 - val_accuracy: 0.6473
# Epoch 187/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6177 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6177 - accuracy: 0.6434 - val_loss: 0.6180 - val_accuracy: 0.6524
# Epoch 188/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6166 - accuracy
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6166 - accuracy: 0.6502 - val_loss: 0.6415 - val_accuracy: 0.6308
# Epoch 189/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6226 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.6226 - accuracy: 0.6415 - val_loss: 0.6434 - val_accuracy: 0.6058
# Epoch 190/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6314 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.6314 - accuracy: 0.6166 - val_loss: 0.6237 - val_accuracy: 0.6528
# Epoch 191/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6087 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.6087 - accuracy: 0.6490 - val_loss: 0.6128 - val_accuracy: 0.6413
# Epoch 192/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.6070 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6070 - accuracy: 0.6524 - val_loss: 0.6080 - val_accuracy: 0.6628
# Epoch 193/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.6005 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.6005 - accuracy: 0.6567 - val_loss: 0.6003 - val_accuracy: 0.6691
# Epoch 194/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.5981 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.5981 - accuracy: 0.6614 - val_loss: 0.5956 - val_accuracy: 0.6611
# Epoch 195/2000
# 7/7 [==============================] - 0s 30ms/step- loss: 0.6102 - accuracy
# 330/330 [==============================] - 24s 72ms/step - loss: 0.6102 - accuracy: 0.6520 - val_loss: 0.5997 - val_accuracy: 0.6737
# Epoch 196/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.5942 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.5942 - accuracy: 0.6693 - val_loss: 0.6021 - val_accuracy: 0.6677
# Epoch 197/2000
# 7/7 [==============================] - 0s 30ms/step- loss: 0.5890 - accuracy
# 330/330 [==============================] - 23s 69ms/step - loss: 0.5890 - accuracy: 0.6753 - val_loss: 0.6170 - val_accuracy: 0.6510
# Epoch 198/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.5985 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.5985 - accuracy: 0.6631 - val_loss: 0.5944 - val_accuracy: 0.6617
# Epoch 199/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.5974 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.5974 - accuracy: 0.6616 - val_loss: 0.5775 - val_accuracy: 0.7035
# Epoch 200/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.5960 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.5960 - accuracy: 0.6662 - val_loss: 0.6003 - val_accuracy: 0.6672
# Epoch 201/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.5968 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.5968 - accuracy: 0.6645 - val_loss: 0.5868 - val_accuracy: 0.6673
# Epoch 202/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.5976 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.5976 - accuracy: 0.6552 - val_loss: 0.5792 - val_accuracy: 0.6997
# Epoch 203/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.5875 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.5875 - accuracy: 0.6724 - val_loss: 0.5906 - val_accuracy: 0.6854
# Epoch 204/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.5838 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.5838 - accuracy: 0.6797 - val_loss: 0.6163 - val_accuracy: 0.6529
# Epoch 205/2000
# 7/7 [==============================] - 0s 25ms/step- loss: 0.5876 - accuracy:
# 330/330 [==============================] - 24s 74ms/step - loss: 0.5876 - accuracy: 0.6755 - val_loss: 0.5859 - val_accuracy: 0.6648
# Epoch 206/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.5773 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.5773 - accuracy: 0.6799 - val_loss: 0.5776 - val_accuracy: 0.6835
# Epoch 207/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.5819 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.5819 - accuracy: 0.6817 - val_loss: 0.5709 - val_accuracy: 0.6935
# Epoch 208/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.5810 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.5810 - accuracy: 0.6787 - val_loss: 0.5807 - val_accuracy: 0.6838
# Epoch 209/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.5769 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.5769 - accuracy: 0.6894 - val_loss: 0.5841 - val_accuracy: 0.6895
# Epoch 210/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.5801 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.5801 - accuracy: 0.6765 - val_loss: 0.5736 - val_accuracy: 0.6844
# Epoch 211/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.5798 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.5798 - accuracy: 0.6794 - val_loss: 0.5602 - val_accuracy: 0.7069
# Epoch 212/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.5735 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.5735 - accuracy: 0.6843 - val_loss: 0.6152 - val_accuracy: 0.6579
# Epoch 213/2000
# ...
# 330/330 [==============================] - 24s 72ms/step - loss: 0.0816 - accuracy: 0.9697 - val_loss: 0.0504 - val_accuracy: 0.9777
# Epoch 506/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.0787 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.0787 - accuracy: 0.9692 - val_loss: 0.0991 - val_accuracy: 0.9560
# Epoch 507/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0908 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.0908 - accuracy: 0.9665 - val_loss: 0.0649 - val_accuracy: 0.9696
# Epoch 508/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0788 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.0788 - accuracy: 0.9687 - val_loss: 0.0462 - val_accuracy: 0.9797
# Epoch 509/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0782 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0782 - accuracy: 0.9698 - val_loss: 0.0820 - val_accuracy: 0.9676
# Epoch 510/2000
# 7/7 [==============================] - 0s 19ms/step- loss: 0.0660 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.0660 - accuracy: 0.9733 - val_loss: 0.0768 - val_accuracy: 0.9685
# Epoch 511/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0800 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0800 - accuracy: 0.9701 - val_loss: 0.0515 - val_accuracy: 0.9773
# Epoch 512/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0634 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0634 - accuracy: 0.9733 - val_loss: 0.0509 - val_accuracy: 0.9779
# Epoch 513/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0711 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.0711 - accuracy: 0.9715 - val_loss: 0.0464 - val_accuracy: 0.9801
# Epoch 514/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0709 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.0709 - accuracy: 0.9718 - val_loss: 0.0554 - val_accuracy: 0.9779
# Epoch 515/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.1160 - accuracy:
# 330/330 [==============================] - 24s 74ms/step - loss: 0.1160 - accuracy: 0.9617 - val_loss: 0.0523 - val_accuracy: 0.9796
# Epoch 516/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0743 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.0743 - accuracy: 0.9714 - val_loss: 0.0632 - val_accuracy: 0.9726
# Epoch 517/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.0723 - accuracy
# 330/330 [==============================] - 24s 72ms/step - loss: 0.0723 - accuracy: 0.9718 - val_loss: 0.0524 - val_accuracy: 0.9776
# Epoch 518/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.0748 - accuracy
# 330/330 [==============================] - 24s 72ms/step - loss: 0.0748 - accuracy: 0.9716 - val_loss: 0.0674 - val_accuracy: 0.9710
# Epoch 519/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.0739 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.0739 - accuracy: 0.9716 - val_loss: 0.0433 - val_accuracy: 0.9804
# Epoch 520/2000
# 7/7 [==============================] - 0s 26ms/step- loss: 0.0911 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.0911 - accuracy: 0.9666 - val_loss: 0.0563 - val_accuracy: 0.9751
# Epoch 521/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0715 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.0715 - accuracy: 0.9715 - val_loss: 0.0465 - val_accuracy: 0.9791
# Epoch 522/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0615 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.0615 - accuracy: 0.9745 - val_loss: 0.0638 - val_accuracy: 0.9757
# Epoch 523/2000
# 7/7 [==============================] - 0s 27ms/step- loss: 0.1026 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.1026 - accuracy: 0.9623 - val_loss: 0.1679 - val_accuracy: 0.9444
# Epoch 524/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0726 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.0726 - accuracy: 0.9718 - val_loss: 0.0503 - val_accuracy: 0.9783
# Epoch 525/2000
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0646 - accuracy:
# 330/330 [==============================] - 24s 71ms/step - loss: 0.0646 - accuracy: 0.9735 - val_loss: 0.2079 - val_accuracy: 0.9475
# Epoch 526/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0695 - accuracy:
# 330/330 [==============================] - 24s 72ms/step - loss: 0.0695 - accuracy: 0.9727 - val_loss: 0.0416 - val_accuracy: 0.9811
# Epoch 527/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0637 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0637 - accuracy: 0.9741 - val_loss: 0.0424 - val_accuracy: 0.9801
# Epoch 528/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0705 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0705 - accuracy: 0.9732 - val_loss: 0.0564 - val_accuracy: 0.9764
# Epoch 529/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0886 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0886 - accuracy: 0.9688 - val_loss: 0.1028 - val_accuracy: 0.9594
# Epoch 530/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0760 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.0760 - accuracy: 0.9712 - val_loss: 0.0443 - val_accuracy: 0.9819
# Epoch 531/2000
# 7/7 [==============================] - 0s 28ms/step- loss: 0.0674 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.0674 - accuracy: 0.9739 - val_loss: 0.0553 - val_accuracy: 0.9744
# Epoch 532/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0628 - accuracy:
# 330/330 [==============================] - 24s 74ms/step - loss: 0.0628 - accuracy: 0.9742 - val_loss: 0.1893 - val_accuracy: 0.9456
# Epoch 533/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0659 - accuracy:
# 330/330 [==============================] - 24s 73ms/step - loss: 0.0659 - accuracy: 0.9737 - val_loss: 0.0430 - val_accuracy: 0.9812
# Epoch 534/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0845 - accuracy:
# 330/330 [==============================] - 25s 74ms/step - loss: 0.0845 - accuracy: 0.9708 - val_loss: 0.0731 - val_accuracy: 0.9720
# Epoch 535/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0748 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0748 - accuracy: 0.9738 - val_loss: 0.0602 - val_accuracy: 0.9741
# Epoch 536/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0808 - accuracy:
# 330/330 [==============================] - 23s 71ms/step - loss: 0.0808 - accuracy: 0.9692 - val_loss: 0.1510 - val_accuracy: 0.9599
# Epoch 537/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0873 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0873 - accuracy: 0.9688 - val_loss: 0.0518 - val_accuracy: 0.9774
# Epoch 538/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0675 - accuracy:
# 330/330 [==============================] - 23s 70ms/step - loss: 0.0675 - accuracy: 0.9729 - val_loss: 0.0488 - val_accuracy: 0.9789
# Epoch 539/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0635 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0635 - accuracy: 0.9747 - val_loss: 0.1048 - val_accuracy: 0.9671
# Epoch 540/2000
# 7/7 [==============================] - 0s 23ms/step- loss: 0.1010 - accuracy:
# 330/330 [==============================] - 23s 68ms/step - loss: 0.1010 - accuracy: 0.9640 - val_loss: 0.0582 - val_accuracy: 0.9727
# Epoch 541/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0799 - accuracy:
# 330/330 [==============================] - 22s 68ms/step - loss: 0.0799 - accuracy: 0.9713 - val_loss: 0.0662 - val_accuracy: 0.9718
# Epoch 542/2000
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0719 - accuracy:
# 330/330 [==============================] - 22s 67ms/step - loss: 0.0719 - accuracy: 0.9729 - val_loss: 0.0638 - val_accuracy: 0.9749
# Epoch 543/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0689 - accuracy:
# 330/330 [==============================] - 23s 69ms/step - loss: 0.0689 - accuracy: 0.9742 - val_loss: 0.0551 - val_accuracy: 0.9768
# Epoch 544/2000
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0564 - accuracy:
# 330/330 [==============================] - 22s 66ms/step - loss: 0.0564 - accuracy: 0.9774 - val_loss: 0.0412 - val_accuracy: 0.9802
# Epoch 545/2000
# 129/330 [==========>...................] - ETA: 12s - loss: 0.0626 - accuracy: 0.9749
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 early_stop=tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=500, verbose=2, mode='auto', baseline=None, restore_best_weights=True)
# ----> 2 model.fit(X_train_Normalizado, y_train_Normalizado, epochs=2000, batch_size=20, callbacks=[tensorboard_callback, cm_callback, early_stop], validation_data=(X_val_def, y_val_def))
#       3 # Final evaluation of the model
#       4 scores = model.evaluate(X_test_def, y_test_def, verbose=0)
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/experimentos_software_2024/envs/tensorflow_2024/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
scores = model.evaluate(X_test_def, y_test_def, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 49.69%

# %%
y_pred = model.predict(X_test_def)
#y_pred2=np.round(y_pred[:,-1]).astype(int)
# esta alternativa no se porque la puse alguna vez
# y_pred2=np.where(y_pred>0,1,0)
# y_pred2=y_pred2[:,-1]
# y_test_def2=np.where(y_test_def>0,1,0)


y_pred2=np.round(y_pred[:,-1]).astype(int)
#y_pred2=np.where(y_pred>0,1,0)
#y_pred2=y_pred2[:,-1]
y_test_def2=y_test_def 
print(y_pred.shape)

print(y_pred[1:10,219,0])
print(y_pred2[1:10])
print(y_test_def2.shape)
#print(y_test_def[25])
# Out:
# 7/7 [==============================] - 0s 24ms/step
# (200, 220, 1)
# [9.9929798e-01 7.2276441e-04 9.9949402e-01 7.5892704e-03 3.3338147e-05
#  3.9058987e-02 9.9964380e-01 8.1368351e-01 9.9954677e-01]
# [[1]
#  [0]
#  [1]
#  [0]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]]
# (200, 1)

# %%
#docs_infra: no_execute

cm=confusion_matrix(y_test_def2, y_pred2)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
# model.save('modelos/modelote1203_200')  # creates a HDF5 file 'my_model.h5'

# %%
model.save('modelos/modelo_perfecto_{}_{}'.format(experimento,datetime.datetime.now().strftime("%Y%m%d-%H%M%S")))

# %%
from scipy import stats
y_pred = model.predict(X_test_def)
#y_pred2 = scaler_out.inverse_transform(y_pred) #valor denormalizado

#y_pred1=y_pred[:,-1]

y_pred2=np.round(y_pred[:,-1]).astype(int)



n = len(y_pred2)
reshaped = y_pred2[:n//4*4].reshape(-1, 4)
mean_values = reshaped.mean(axis=1)

mean_values = np.round(mean_values)
mean_values = np.clip(mean_values, 0, 4)
mean_values = mean_values.astype(int)
print(mean_values)

mode_values = stats.mode(reshaped, axis=1)[0]
print(mode_values)

# Convierte los arrays a DataFrames
mean_df = pd.DataFrame(mean_values, columns=['mean'])
mode_df = pd.DataFrame(mode_values, columns=['mode'])

# Guarda los DataFrames en archivos Excel
mean_df.to_excel("clasificacion_bipolar_P2_mean_best7.xlsx", index=False)
mode_df.to_excel("clasificacion_bipolar_P2_mode_best7.xlsx", index=False)
