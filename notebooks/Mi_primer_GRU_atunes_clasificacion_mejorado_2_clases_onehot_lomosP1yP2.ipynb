# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM,Bidirectional,GRU
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical
import datetime
import io
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

import sys
import os
# Obtener la ruta del directorio actual
os.chdir('/home/rgadea/experimentos_software_2024')
current_dir = os.getcwd()
print(current_dir)

# Construir la ruta relativa al directorio que quieres agregar
relative_dir = os.path.join(current_dir, 'mis_pkgs/')

# Agregar la ruta relativa al sys.path
sys.path.insert(0, relative_dir)

from MIOPATIA_db import DB_management as db
# Out:
# 2024-05-13 10:04:12.721791: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-13 10:04:12.721839: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-13 10:04:12.723439: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-13 10:04:12.734541: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-13 10:04:13.521467: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/rgadea/experimentos_software_2024

# %% [markdown]
# Voy a quedarme con los 50 atunes P1 para obtener conjunto de training y validacion

# %%
# !pwd
# Out:
# /home/rgadea/experimentos_software_2024

# %%
filename = "lomosP1_20240430_clasificado_experto_ampliado_the_best7.hdf"
with pd.HDFStore(filename,complib="zlib",complevel=4) as hdf_db:
    pre_p_e1  = hdf_db.get('data/pollos_estado')
    pre_p_e1 = pre_p_e1.loc[pre_p_e1['Pollo'] != 0]
    # p_e =pre_p_e1.drop_duplicates(subset = ['Pollo', 'Medida'],  keep = 'last').reset_index(drop = True)
    t    = hdf_db.get('data/tabla')
    X_train=np.zeros((pre_p_e1.shape[0],220,8))
    y_train=np.zeros((pre_p_e1.shape[0],1))
    x=0
    for index, row in pre_p_e1.iterrows():   # El primer registro no se toma en cuenta porque es basura
        Primero = int(row['Primero'])
        Ultimo  = int(row['Ultimo'])
        estado  = int(row['Estado'])
        #print(Primero)
        #print(Ultimo)
        #print(estado)
        if estado == 0 or estado== 1:
            target = 1
        else:
            target = 0
        #target=estado
        pepito=np.array(t.iloc[Primero:Ultimo+1])
        # #print(pepito.shape)
        X_train[x]=pepito[:,3:11]
        #print(X_train[x][0:4,:])       
        y_train[x]=target
        y_train_to_categorical = to_categorical(y_train)
        x=x+1


# print(X_train.shape)
# print(y_train_to_categorical.shape)
# #print(X_train[0:4,:,:])
# #print(X_train[1][0:4][:])
# print(y_train[1:20])
# print(y_train_to_categorical[1:20])
# # #Aqui filtrariamos si hay filas que no nos interesan. En este caso dejo pasar todos los casos
# print(p_e)
# # X_train_filtrado = X_train[2:][:,:]
# # y_train_filtrado = y_train[2:]
X_train_filtrado = X_train
#y_train_filtrado = y_train
y_train_filtrado = y_train_to_categorical

# print(X_train_filtrado.shape)
# print(y_train_filtrado.shape)
# print(X_train_filtrado[0][:,:])
# # # Vamos a normalizar o escalar los datos
scaler = MinMaxScaler(feature_range=(0, 1))
data_2d = X_train_filtrado.reshape(-1, X_train_filtrado.shape[-1])
normalized_data_2d = scaler.fit_transform(data_2d)
X_train_Normalizado=normalized_data_2d.reshape(X_train_filtrado.shape)
y_train_Normalizado=y_train_filtrado # los valores ya estaban normalizados
print(X_train_Normalizado[0])
# Out:
# [[8.61839703e-05 5.64525281e-01 6.19466028e-01 ... 4.35474806e-01
#   8.61942186e-05 9.54751150e-01]
#  [7.95233660e-05 5.52105715e-01 6.74466323e-01 ... 4.47894371e-01
#   7.95325941e-05 9.54747869e-01]
#  [7.82429225e-05 5.53651114e-01 6.62216186e-01 ... 4.46348972e-01
#   7.82520425e-05 9.54748691e-01]
#  ...
#  [1.07084974e-05 3.79849460e-01 4.68148628e-01 ... 6.20150599e-01
#   1.07083027e-05 9.54753309e-01]
#  [1.02172207e-05 3.77571475e-01 4.68149136e-01 ... 6.22428584e-01
#   1.02169998e-05 9.54753658e-01]
#  [9.71743706e-06 3.75437107e-01 4.68150028e-01 ... 6.24562951e-01
#   9.71719475e-06 9.54754033e-01]]

# %%
filename = "lomosP2_20240430_clasificado_experto.hdf"
with pd.HDFStore(filename,complib="zlib",complevel=4) as hdf_db:
    pre_p_e1  = hdf_db.get('data/pollos_estado')
    pre_p_e1 = pre_p_e1.loc[pre_p_e1['Pollo'] != 0]
    pre_p_e1 =pre_p_e1.drop_duplicates(subset = ['Pollo', 'Medida'],  keep = 'last').reset_index(drop = True)
    t    = hdf_db.get('data/tabla')
    X_test=np.zeros((pre_p_e1.shape[0],220,8))
    y_test=np.zeros((pre_p_e1.shape[0],1))
    x=0
    for index, row in pre_p_e1.iterrows():   # El primer registro no se toma en cuenta porque es basura
        Primero = int(row['Primero'])
        Ultimo  = int(row['Ultimo'])
        estado  = int(row['Estado'])
        #print(Primero)
        #print(Ultimo)
        #print(estado)
        if estado == 0 or estado== 1:
           target = 1
        else:
           target = 0
        #target=estado
        pepito=np.array(t.iloc[Primero:Ultimo+1])
        # #print(pepito.shape)
        X_test[x]=pepito[:,3:11]
        #print(X_train[x][0:4,:])       
        y_test[x]=target
        y_test_to_categorical = to_categorical(y_test)
        x=x+1


# print(X_train.shape)
# print(y_train_to_categorical.shape)
# #print(X_train[0:4,:,:])
# #print(X_train[1][0:4][:])
# print(y_train[1:20])
# print(y_train_to_categorical[1:20])
# # #Aqui filtrariamos si hay filas que no nos interesan. En este caso dejo pasar todos los casos
# print(p_e)
# # X_train_filtrado = X_train[2:][:,:]
# # y_train_filtrado = y_train[2:]
X_test_filtrado = X_test
#y_train_filtrado = y_train
y_test_filtrado = y_test_to_categorical

print(X_test_filtrado.shape)
print(y_test_filtrado.shape)
# print(X_train_filtrado[0][:,:])
# # # Vamos a normalizar o escalar los datos
# concatenamos train y test
#X_total=np.concatenate((X_train_filtrado,X_test_filtrado),axis=0)
#scaler = MinMaxScaler(feature_range=(0, 1))
#data_2d_test = X_total.reshape(-1, X_total.shape[-1])
data_2d_test = X_test_filtrado.reshape(-1, X_test_filtrado.shape[-1])
normalized_data_2d_test = scaler.transform(data_2d_test)


X_test_def=normalized_data_2d_test.reshape(X_test_filtrado.shape) 
# la alternativa es normalizar con el total
# X_test_def=normalized_data_2d_test.reshape(X_test_filtrado.shape) 

y_test_def=y_test_filtrado # los valores ya estaban normalizados
print(X_test_def[0])
# Out:
# (200, 220, 8)
# (200, 5)
# [[4.99025807e-04 5.80020116e-01 4.83981454e-01 ... 4.19979974e-01
#   4.99084819e-04 9.54715517e-01]
#  [4.75705014e-04 5.79517317e-01 4.84351313e-01 ... 4.20482773e-01
#   4.75761253e-04 9.54716827e-01]
#  [4.67506069e-04 5.79997825e-01 4.83558957e-01 ... 4.20002265e-01
#   4.67561374e-04 9.54718645e-01]
#  ...
#  [5.17572486e-06 3.80559824e-01 4.68334602e-01 ... 6.19440235e-01
#   5.17564751e-06 9.54758673e-01]
#  [4.87404572e-06 3.84780844e-01 4.68323649e-01 ... 6.15219216e-01
#   4.87401208e-06 9.54759097e-01]
#  [4.56535078e-06 3.89543117e-01 4.68312881e-01 ... 6.10456944e-01
#   4.56536162e-06 9.54759533e-01]]

# %% [markdown]
# Vamos a hacer los conjuntos de entrenamiento validacion y test

# %%
# Divide el dataset en entrenamiento y temporal (test+validación)
# X_temp, X_test_def, y_temp, y_test_def = train_test_split(X_train_Normalizado, y_train_Normalizado, test_size=0.2, stratify=y_train_Normalizado, random_state=42)

# Divide el dataset temporal en validación y test
X_train_def, X_val_def, y_train_def, y_val_def = train_test_split(X_train_Normalizado, y_train_Normalizado, test_size=0.25, stratify=y_train_Normalizado, random_state=42)

# Ahora, X_train, X_val y X_test contienen los datos de entrada para los conjuntos de entrenamiento, validación y prueba, respectivamente.
# y_train, y_val y y_test contienen las clases correspondientes.

# %%
print(X_train_def.shape)
print(X_val_def.shape)
print(X_test_def.shape)
print(y_train_def.shape)
print(y_val_def.shape)
print(y_test_def.shape)
# Out:
# (4999, 220, 8)
# (1667, 220, 8)
# (200, 220, 8)
# (4999, 5)
# (1667, 5)
# (200, 5)

# %%
# %load_ext tensorboard

#%tensorboard --logdir logs
#log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
#tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
def plot_to_image(figure):
    """
    Converts the matplotlib plot specified by 'figure' to a PNG image and
    returns it. The supplied figure is closed and inaccessible after this call.
    """
    
    buf = io.BytesIO()
    
    # Use plt.savefig to save the plot to a PNG in memory.
    plt.savefig(buf, format='png')
    
    # Closing the figure prevents it from being displayed directly inside
    # the notebook.
    plt.close(figure)
    buf.seek(0)
    
    # Use tf.image.decode_png to convert the PNG buffer
    # to a TF image. Make sure you use 4 channels.
    image = tf.image.decode_png(buf.getvalue(), channels=4)
    
    # Use tf.expand_dims to add the batch dimension
    image = tf.expand_dims(image, 0)
    
    return image

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Returns a matplotlib figure containing the plotted confusion matrix.
    
    Args:
       cm (array, shape = [n, n]): a confusion matrix of integer classes
       class_names (array, shape = [n]): String names of the integer classes
    """
    
    figure = plt.figure(figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)
    
    # Normalize the confusion matrix.
    cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)
    
    # Use white text if squares are dark; otherwise black.
    threshold = cm.max() / 2.
    threshold = 0.5
    
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "red" if cm[i, j] > threshold else "black"
        plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return figure

# %%
algoritmo='RMSprop'
supermax=8*4
lossfunction='categorical_crossentropy'
factor_aprendizaje=0.001
dimension_LSTM=50
dimension_dense=50
model = Sequential()
model.add(GRU(dimension_LSTM, return_sequences=False,input_shape=(220, 8)))
#model.add(Bidirectional(LSTM(50, return_sequences=True)))
#model.add(Bidirectional(LSTM(50, return_sequences=True)))
#model.add(Bidirectional(LSTM(50, return_sequences=False)))
model.add(Dense(dimension_dense, activation='tanh'))
model.add(Dense(5, activation='softmax'))
model.compile(loss=lossfunction, optimizer=algoritmo, metrics=['accuracy'])
model.optimizer.lr=(factor_aprendizaje)
print(model.summary())

experimento="LOMOS_P2_y_P1_GRU2_2_clases_{}_dense_onehot_{}_loss_{}_lr_{}_algoritmo_{}".format(dimension_LSTM,dimension_dense,lossfunction,factor_aprendizaje,algoritmo)
logdir="./logs/defs/{}_{}".format(experimento,datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback=tf.keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1)
file_writer_cm = tf.summary.create_file_writer(logdir + '/cm')
# Out:
# 2024-05-13 10:04:20.198786: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2024-05-13 10:04:20.198912: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:129] retrieving CUDA diagnostic information for host: nodofpga-2024.novalocal
# 2024-05-13 10:04:20.198948: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:136] hostname: nodofpga-2024.novalocal
# 2024-05-13 10:04:20.199297: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:159] libcuda reported version is: 535.161.7
# 2024-05-13 10:04:20.199438: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] kernel reported version is: 535.161.7
# 2024-05-13 10:04:20.199459: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:241] kernel version seems to match DSO: 535.161.7
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 50)                9000
#
#  dense (Dense)               (None, 50)                2550
#
#  dense_1 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 11805 (46.11 KB)
# Trainable params: 11805 (46.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
class_names=["Buenos","Malos"]

# %%
def log_confusion_matrix(epoch, logs):
    
    # Use the model to predict the values from the test_images.
    y_pred = model.predict(X_test_def)
    #y_pred1=y_pred[:,-1]
    y_pred2=y_pred.argmax(axis=1)
    #y_pred2=np.where(y_pred>0,1,0)
    #y_pred2=y_pred2[:,-1]
    #classes = [0, 1, 2, 3, 4] 
    classes = [0, 1]
    y_test_def2=np.argmax(y_test_def,axis=1)  
    #y_test_def2=np.where(y_test_def>0,1,0)
    cm=confusion_matrix(y_test_def2, y_pred2,labels=classes)
    # disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    figura = plot_confusion_matrix(cm, class_names=class_names)
    cm_image = plot_to_image(figura)
    
    # Log the confusion matrix as an image summary.
    with file_writer_cm.as_default():
        tf.summary.image("Confusion Matrix", cm_image, step=epoch)

# %%
cm_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)
print(y_train_Normalizado.shape)
print(y_val_def.shape)
# Out:
# (6666, 5)
# (1667, 5)

# %%
early_stop=tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=500, verbose=2, mode='auto', baseline=None, restore_best_weights=True)
model.fit(X_train_Normalizado, y_train_Normalizado, epochs=400, batch_size=20, callbacks=[tensorboard_callback,cm_callback, early_stop], validation_data=(X_val_def, y_val_def))
# Final evaluation of the model 
scores = model.evaluate(X_test_def, y_test_def, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/400
# 7/7 [==============================] - 1s 20ms/step- loss: 1.4832 - accuracy:
# 334/334 [==============================] - 32s 92ms/step - loss: 1.4832 - accuracy: 0.3638 - val_loss: 1.4719 - val_accuracy: 0.3665
# Epoch 2/400
# 7/7 [==============================] - 0s 27ms/step- loss: 1.4702 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 1.4702 - accuracy: 0.3665 - val_loss: 1.4648 - val_accuracy: 0.3641
# Epoch 3/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.4654 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.4654 - accuracy: 0.3744 - val_loss: 1.4644 - val_accuracy: 0.3719
# Epoch 4/400
# 7/7 [==============================] - 0s 26ms/step- loss: 1.4636 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.4636 - accuracy: 0.3747 - val_loss: 1.4625 - val_accuracy: 0.3725
# Epoch 5/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.4605 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.4605 - accuracy: 0.3744 - val_loss: 1.4608 - val_accuracy: 0.3701
# Epoch 6/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4618 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 1.4618 - accuracy: 0.3741 - val_loss: 1.4612 - val_accuracy: 0.3659
# Epoch 7/400
# 7/7 [==============================] - 0s 19ms/step- loss: 1.4597 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.4597 - accuracy: 0.3762 - val_loss: 1.4632 - val_accuracy: 0.3719
# Epoch 8/400
# 7/7 [==============================] - 0s 25ms/step- loss: 1.4600 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.4600 - accuracy: 0.3744 - val_loss: 1.4629 - val_accuracy: 0.3665
# Epoch 9/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4595 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 1.4595 - accuracy: 0.3776 - val_loss: 1.4574 - val_accuracy: 0.3647
# Epoch 10/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4583 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.4583 - accuracy: 0.3776 - val_loss: 1.4583 - val_accuracy: 0.3653
# Epoch 11/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.4589 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.4589 - accuracy: 0.3779 - val_loss: 1.4627 - val_accuracy: 0.3767
# Epoch 12/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4585 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.4585 - accuracy: 0.3758 - val_loss: 1.4571 - val_accuracy: 0.3797
# Epoch 13/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4581 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.4581 - accuracy: 0.3798 - val_loss: 1.4620 - val_accuracy: 0.3755
# Epoch 14/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.4534 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.4534 - accuracy: 0.3815 - val_loss: 1.4711 - val_accuracy: 0.3701
# Epoch 15/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4521 - accuracy:
# 334/334 [==============================] - 27s 82ms/step - loss: 1.4521 - accuracy: 0.3798 - val_loss: 1.4523 - val_accuracy: 0.3761
# Epoch 16/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4465 - accuracy:
# 334/334 [==============================] - 30s 90ms/step - loss: 1.4465 - accuracy: 0.3785 - val_loss: 1.4440 - val_accuracy: 0.3803
# Epoch 17/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4429 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.4429 - accuracy: 0.3818 - val_loss: 1.4459 - val_accuracy: 0.3695
# Epoch 18/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4405 - accuracy:
# 334/334 [==============================] - 30s 90ms/step - loss: 1.4405 - accuracy: 0.3906 - val_loss: 1.4676 - val_accuracy: 0.4175
# Epoch 19/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4367 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 1.4367 - accuracy: 0.3884 - val_loss: 1.4327 - val_accuracy: 0.3923
# Epoch 20/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.4347 - accuracy:
# 334/334 [==============================] - 27s 81ms/step - loss: 1.4347 - accuracy: 0.3920 - val_loss: 1.4351 - val_accuracy: 0.4043
# Epoch 21/400
# 7/7 [==============================] - 0s 23ms/step- loss: 1.4326 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 1.4326 - accuracy: 0.3938 - val_loss: 1.4330 - val_accuracy: 0.4055
# Epoch 22/400
# 7/7 [==============================] - 0s 18ms/step- loss: 1.4315 - accuracy: 0.
# 334/334 [==============================] - 28s 85ms/step - loss: 1.4315 - accuracy: 0.3966 - val_loss: 1.4187 - val_accuracy: 0.4019
# Epoch 23/400
# 7/7 [==============================] - 0s 24ms/step- loss: 1.4249 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 1.4249 - accuracy: 0.3942 - val_loss: 1.4602 - val_accuracy: 0.3929
# Epoch 24/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4182 - accuracy:
# 334/334 [==============================] - 31s 93ms/step - loss: 1.4182 - accuracy: 0.3980 - val_loss: 1.4293 - val_accuracy: 0.3827
# Epoch 25/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.3996 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.3996 - accuracy: 0.4037 - val_loss: 1.3916 - val_accuracy: 0.4067
# Epoch 26/400
# 7/7 [==============================] - 0s 25ms/step- loss: 1.3831 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.3831 - accuracy: 0.4034 - val_loss: 1.6807 - val_accuracy: 0.3413
# Epoch 27/400
# 7/7 [==============================] - 0s 25ms/step- loss: 1.3730 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 1.3730 - accuracy: 0.4110 - val_loss: 1.6164 - val_accuracy: 0.3707
# Epoch 28/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.3538 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 1.3538 - accuracy: 0.4176 - val_loss: 1.4730 - val_accuracy: 0.3881
# Epoch 29/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.3496 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 1.3496 - accuracy: 0.4263 - val_loss: 1.4888 - val_accuracy: 0.3689
# Epoch 30/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4581 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.4581 - accuracy: 0.3803 - val_loss: 1.4385 - val_accuracy: 0.4043
# Epoch 31/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4210 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.4210 - accuracy: 0.3971 - val_loss: 1.4060 - val_accuracy: 0.3815
# Epoch 32/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.4034 - accuracy:
# /tmp/ipykernel_5124/35999282.py:19: RuntimeWarning: invalid value encountered in divide
#   cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)
# 334/334 [==============================] - 28s 85ms/step - loss: 1.4034 - accuracy: 0.4007 - val_loss: 1.4877 - val_accuracy: 0.2873
# Epoch 33/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.3843 - accuracy:
# /tmp/ipykernel_5124/35999282.py:19: RuntimeWarning: invalid value encountered in divide
#   cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)
# 334/334 [==============================] - 29s 85ms/step - loss: 1.3843 - accuracy: 0.3993 - val_loss: 1.3865 - val_accuracy: 0.4067
# Epoch 34/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.3574 - accuracy:
# /tmp/ipykernel_5124/35999282.py:19: RuntimeWarning: invalid value encountered in divide
#   cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)
# 334/334 [==============================] - 27s 82ms/step - loss: 1.3574 - accuracy: 0.4181 - val_loss: 1.3203 - val_accuracy: 0.4457
# Epoch 35/400
# 7/7 [==============================] - 0s 23ms/step- loss: 1.3593 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 1.3593 - accuracy: 0.4178 - val_loss: 1.3876 - val_accuracy: 0.4103
# Epoch 36/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.3553 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.3553 - accuracy: 0.4223 - val_loss: 1.3443 - val_accuracy: 0.4259
# Epoch 37/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.3216 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 1.3216 - accuracy: 0.4419 - val_loss: 1.3152 - val_accuracy: 0.4535
# Epoch 38/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.3115 - accuracy:
# 334/334 [==============================] - 27s 82ms/step - loss: 1.3115 - accuracy: 0.4553 - val_loss: 1.2501 - val_accuracy: 0.4709
# Epoch 39/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.3039 - accuracy:
# 334/334 [==============================] - 26s 77ms/step - loss: 1.3039 - accuracy: 0.4553 - val_loss: 1.2536 - val_accuracy: 0.4655
# Epoch 40/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.2694 - accuracy:
# 334/334 [==============================] - 24s 73ms/step - loss: 1.2694 - accuracy: 0.4701 - val_loss: 1.1955 - val_accuracy: 0.4943
# Epoch 41/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.2491 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 1.2491 - accuracy: 0.4733 - val_loss: 1.2651 - val_accuracy: 0.4661
# Epoch 42/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.2307 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.2307 - accuracy: 0.4871 - val_loss: 1.2790 - val_accuracy: 0.4745
# Epoch 43/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.2127 - accuracy:
# 334/334 [==============================] - 27s 82ms/step - loss: 1.2127 - accuracy: 0.4947 - val_loss: 1.2138 - val_accuracy: 0.4829
# Epoch 44/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.2176 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 1.2176 - accuracy: 0.4920 - val_loss: 1.2878 - val_accuracy: 0.4691
# Epoch 45/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.1997 - accuracy:
# 334/334 [==============================] - 27s 81ms/step - loss: 1.1997 - accuracy: 0.5027 - val_loss: 1.5685 - val_accuracy: 0.3701
# Epoch 46/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.1788 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.1788 - accuracy: 0.5032 - val_loss: 1.3895 - val_accuracy: 0.4625
# Epoch 47/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.1731 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.1731 - accuracy: 0.5017 - val_loss: 1.1520 - val_accuracy: 0.4829
# Epoch 48/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.1425 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.1425 - accuracy: 0.5152 - val_loss: 1.1026 - val_accuracy: 0.5177
# Epoch 49/400
# 7/7 [==============================] - 0s 19ms/step- loss: 1.1416 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.1416 - accuracy: 0.5159 - val_loss: 1.3739 - val_accuracy: 0.4691
# Epoch 50/400
# 7/7 [==============================] - 0s 24ms/step- loss: 1.1577 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.1577 - accuracy: 0.5089 - val_loss: 1.4556 - val_accuracy: 0.3809
# Epoch 51/400
# 7/7 [==============================] - 0s 24ms/step- loss: 1.1706 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 1.1706 - accuracy: 0.5063 - val_loss: 1.1095 - val_accuracy: 0.5339
# Epoch 52/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.1469 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.1469 - accuracy: 0.5095 - val_loss: 1.1521 - val_accuracy: 0.5291
# Epoch 53/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.1233 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.1233 - accuracy: 0.5186 - val_loss: 1.1255 - val_accuracy: 0.4745
# Epoch 54/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.1073 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.1073 - accuracy: 0.5191 - val_loss: 1.2710 - val_accuracy: 0.4685
# Epoch 55/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.1073 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.1073 - accuracy: 0.5320 - val_loss: 1.1103 - val_accuracy: 0.5483
# Epoch 56/400
# 7/7 [==============================] - 0s 23ms/step- loss: 1.0771 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.0771 - accuracy: 0.5351 - val_loss: 1.0889 - val_accuracy: 0.5219
# Epoch 57/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.0742 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 1.0742 - accuracy: 0.5321 - val_loss: 0.9934 - val_accuracy: 0.5675
# Epoch 58/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.0614 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.0614 - accuracy: 0.5425 - val_loss: 0.9973 - val_accuracy: 0.5879
# Epoch 59/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.0488 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 1.0488 - accuracy: 0.5524 - val_loss: 0.9548 - val_accuracy: 0.5819
# Epoch 60/400
# 7/7 [==============================] - 0s 22ms/step- loss: 1.0397 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 1.0397 - accuracy: 0.5464 - val_loss: 1.0009 - val_accuracy: 0.5729
# Epoch 61/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.0621 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.0621 - accuracy: 0.5449 - val_loss: 1.1212 - val_accuracy: 0.5225
# Epoch 62/400
# 7/7 [==============================] - 0s 21ms/step- loss: 1.0678 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 1.0678 - accuracy: 0.5525 - val_loss: 1.0745 - val_accuracy: 0.5423
# Epoch 63/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.0130 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 1.0130 - accuracy: 0.5773 - val_loss: 1.3856 - val_accuracy: 0.4889
# Epoch 64/400
# 7/7 [==============================] - 0s 28ms/step- loss: 1.0270 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 1.0270 - accuracy: 0.5783 - val_loss: 1.1257 - val_accuracy: 0.5159
# Epoch 65/400
# 7/7 [==============================] - 0s 20ms/step- loss: 1.0061 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 1.0061 - accuracy: 0.5825 - val_loss: 0.9023 - val_accuracy: 0.6221
# Epoch 66/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.9942 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.9942 - accuracy: 0.5791 - val_loss: 0.9458 - val_accuracy: 0.6353
# Epoch 67/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.9637 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.9637 - accuracy: 0.5971 - val_loss: 0.8690 - val_accuracy: 0.6413
# Epoch 68/400
# 7/7 [==============================] - 0s 27ms/step- loss: 0.9964 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.9964 - accuracy: 0.5975 - val_loss: 1.4780 - val_accuracy: 0.4463
# Epoch 69/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.9462 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.9462 - accuracy: 0.6062 - val_loss: 1.2015 - val_accuracy: 0.5051
# Epoch 70/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.9422 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.9422 - accuracy: 0.6155 - val_loss: 1.0152 - val_accuracy: 0.5747
# Epoch 71/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.9092 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.9092 - accuracy: 0.6320 - val_loss: 0.8863 - val_accuracy: 0.6479
# Epoch 72/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.9012 - accuracy:
# 334/334 [==============================] - 27s 80ms/step - loss: 0.9012 - accuracy: 0.6262 - val_loss: 0.8928 - val_accuracy: 0.6203
# Epoch 73/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.9026 - accuracy:
# 334/334 [==============================] - 28s 82ms/step - loss: 0.9026 - accuracy: 0.6271 - val_loss: 0.9256 - val_accuracy: 0.5861
# Epoch 74/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.8847 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.8847 - accuracy: 0.6307 - val_loss: 0.9101 - val_accuracy: 0.6221
# Epoch 75/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.8620 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.8620 - accuracy: 0.6422 - val_loss: 0.8240 - val_accuracy: 0.6623
# Epoch 76/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.8460 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.8460 - accuracy: 0.6572 - val_loss: 0.7942 - val_accuracy: 0.6947
# Epoch 77/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.8066 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.8066 - accuracy: 0.6803 - val_loss: 0.9384 - val_accuracy: 0.6221
# Epoch 78/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.8166 - accuracy:
# 334/334 [==============================] - 27s 82ms/step - loss: 0.8166 - accuracy: 0.6721 - val_loss: 0.8984 - val_accuracy: 0.6443
# Epoch 79/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.7930 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.7930 - accuracy: 0.6815 - val_loss: 0.7531 - val_accuracy: 0.6989
# Epoch 80/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.7755 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.7755 - accuracy: 0.6908 - val_loss: 0.9141 - val_accuracy: 0.6113
# Epoch 81/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.8307 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.8307 - accuracy: 0.6647 - val_loss: 0.8521 - val_accuracy: 0.6569
# Epoch 82/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.7806 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.7806 - accuracy: 0.6781 - val_loss: 0.7763 - val_accuracy: 0.6737
# Epoch 83/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.7497 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.7497 - accuracy: 0.6955 - val_loss: 0.5932 - val_accuracy: 0.7696
# Epoch 84/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.7157 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.7157 - accuracy: 0.7091 - val_loss: 0.6375 - val_accuracy: 0.7427
# Epoch 85/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6930 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.6930 - accuracy: 0.7183 - val_loss: 0.8205 - val_accuracy: 0.6593
# Epoch 86/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6871 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.6871 - accuracy: 0.7211 - val_loss: 0.6938 - val_accuracy: 0.7109
# Epoch 87/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.6598 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.6598 - accuracy: 0.7394 - val_loss: 1.1876 - val_accuracy: 0.5459
# Epoch 88/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.6332 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.6332 - accuracy: 0.7444 - val_loss: 0.5578 - val_accuracy: 0.7714
# Epoch 89/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.6242 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.6242 - accuracy: 0.7525 - val_loss: 0.5397 - val_accuracy: 0.7684
# Epoch 90/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6204 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.6204 - accuracy: 0.7481 - val_loss: 0.8397 - val_accuracy: 0.6719
# Epoch 91/400
# 7/7 [==============================] - 0s 17ms/step- loss: 0.6050 - accuracy: 0.
# 334/334 [==============================] - 30s 90ms/step - loss: 0.6050 - accuracy: 0.7586 - val_loss: 0.7365 - val_accuracy: 0.7019
# Epoch 92/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.5744 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.5744 - accuracy: 0.7690 - val_loss: 0.4941 - val_accuracy: 0.7948
# Epoch 93/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.5690 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.5690 - accuracy: 0.7781 - val_loss: 0.4715 - val_accuracy: 0.8194
# Epoch 94/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.5576 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.5576 - accuracy: 0.7813 - val_loss: 0.4926 - val_accuracy: 0.8032
# Epoch 95/400
# 7/7 [==============================] - 0s 26ms/step- loss: 0.5472 - accuracy:
# 334/334 [==============================] - 30s 90ms/step - loss: 0.5472 - accuracy: 0.7826 - val_loss: 0.9061 - val_accuracy: 0.6731
# Epoch 96/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.5611 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.5611 - accuracy: 0.7861 - val_loss: 0.7050 - val_accuracy: 0.6941
# Epoch 97/400
# 7/7 [==============================] - 0s 27ms/step- loss: 0.5269 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.5269 - accuracy: 0.7919 - val_loss: 0.5823 - val_accuracy: 0.7367
# Epoch 98/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.5083 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.5083 - accuracy: 0.7961 - val_loss: 1.0223 - val_accuracy: 0.5831
# Epoch 99/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.5483 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.5483 - accuracy: 0.7928 - val_loss: 0.6788 - val_accuracy: 0.7397
# Epoch 100/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.5099 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.5099 - accuracy: 0.7994 - val_loss: 0.3788 - val_accuracy: 0.8722
# Epoch 101/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.4728 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.4728 - accuracy: 0.8165 - val_loss: 0.4259 - val_accuracy: 0.8278
# Epoch 102/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.4732 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.4732 - accuracy: 0.8126 - val_loss: 0.4405 - val_accuracy: 0.8398
# Epoch 103/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.4658 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.4658 - accuracy: 0.8198 - val_loss: 0.6654 - val_accuracy: 0.7001
# Epoch 104/400
# 7/7 [==============================] - 0s 27ms/step- loss: 0.4520 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.4520 - accuracy: 0.8261 - val_loss: 0.3280 - val_accuracy: 0.8674
# Epoch 105/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.4560 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.4560 - accuracy: 0.8245 - val_loss: 0.8639 - val_accuracy: 0.7037
# Epoch 106/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.4331 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.4331 - accuracy: 0.8354 - val_loss: 0.7678 - val_accuracy: 0.7007
# Epoch 107/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.6047 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.6047 - accuracy: 0.7909 - val_loss: 0.6854 - val_accuracy: 0.7606
# Epoch 108/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.4438 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.4438 - accuracy: 0.8317 - val_loss: 0.3364 - val_accuracy: 0.8752
# Epoch 109/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.4262 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.4262 - accuracy: 0.8347 - val_loss: 0.6259 - val_accuracy: 0.7606
# Epoch 110/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.4197 - accuracy:
# 334/334 [==============================] - 27s 82ms/step - loss: 0.4197 - accuracy: 0.8384 - val_loss: 0.2714 - val_accuracy: 0.9004
# Epoch 111/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.4131 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.4131 - accuracy: 0.8413 - val_loss: 0.3903 - val_accuracy: 0.8542
# Epoch 112/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.4066 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.4066 - accuracy: 0.8468 - val_loss: 0.6191 - val_accuracy: 0.7642
# Epoch 113/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.4144 - accuracy:
# 334/334 [==============================] - 30s 89ms/step - loss: 0.4144 - accuracy: 0.8429 - val_loss: 0.4584 - val_accuracy: 0.8020
# Epoch 114/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.3950 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.3950 - accuracy: 0.8491 - val_loss: 0.4858 - val_accuracy: 0.8194
# Epoch 115/400
# 7/7 [==============================] - 0s 26ms/step- loss: 0.3755 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.3755 - accuracy: 0.8597 - val_loss: 0.4754 - val_accuracy: 0.8302
# Epoch 116/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.3817 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.3817 - accuracy: 0.8599 - val_loss: 0.2206 - val_accuracy: 0.9280
# Epoch 117/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.4026 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.4026 - accuracy: 0.8540 - val_loss: 0.3360 - val_accuracy: 0.8620
# Epoch 118/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.3481 - accuracy:
# 334/334 [==============================] - 26s 79ms/step - loss: 0.3481 - accuracy: 0.8731 - val_loss: 0.6672 - val_accuracy: 0.7606
# Epoch 119/400
# 7/7 [==============================] - 0s 18ms/step- loss: 0.3378 - accuracy:
# 334/334 [==============================] - 27s 80ms/step - loss: 0.3378 - accuracy: 0.8723 - val_loss: 0.3691 - val_accuracy: 0.8434
# Epoch 120/400
# 7/7 [==============================] - 0s 18ms/step- loss: 0.3415 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.3415 - accuracy: 0.8717 - val_loss: 0.6716 - val_accuracy: 0.7528
# Epoch 121/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.3378 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.3378 - accuracy: 0.8722 - val_loss: 0.5439 - val_accuracy: 0.7912
# Epoch 122/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.3197 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.3197 - accuracy: 0.8809 - val_loss: 0.3482 - val_accuracy: 0.8746
# Epoch 123/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.3498 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.3498 - accuracy: 0.8737 - val_loss: 0.3922 - val_accuracy: 0.8518
# Epoch 124/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.3363 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.3363 - accuracy: 0.8803 - val_loss: 0.5757 - val_accuracy: 0.7960
# Epoch 125/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.3312 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.3312 - accuracy: 0.8816 - val_loss: 0.2278 - val_accuracy: 0.9208
# Epoch 126/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.2982 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.2982 - accuracy: 0.8908 - val_loss: 0.4098 - val_accuracy: 0.8248
# Epoch 127/400
# 7/7 [==============================] - 0s 29ms/step- loss: 0.3697 - accuracy
# 334/334 [==============================] - 29s 86ms/step - loss: 0.3697 - accuracy: 0.8786 - val_loss: 0.3494 - val_accuracy: 0.8422
# Epoch 128/400
# 7/7 [==============================] - 0s 18ms/step- loss: 0.3019 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.3019 - accuracy: 0.8950 - val_loss: 0.6597 - val_accuracy: 0.7528
# Epoch 129/400
# 7/7 [==============================] - 0s 27ms/step- loss: 0.2855 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.2855 - accuracy: 0.8977 - val_loss: 0.6437 - val_accuracy: 0.7636
# Epoch 130/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.3113 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.3113 - accuracy: 0.8848 - val_loss: 0.2173 - val_accuracy: 0.9100
# Epoch 131/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.3166 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.3166 - accuracy: 0.8881 - val_loss: 0.1641 - val_accuracy: 0.9484
# Epoch 132/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.2963 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.2963 - accuracy: 0.8908 - val_loss: 0.3270 - val_accuracy: 0.8692
# Epoch 133/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.2743 - accuracy:
# 334/334 [==============================] - 27s 82ms/step - loss: 0.2743 - accuracy: 0.8990 - val_loss: 0.3182 - val_accuracy: 0.8860
# Epoch 134/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.2653 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.2653 - accuracy: 0.9080 - val_loss: 0.2234 - val_accuracy: 0.9010
# Epoch 135/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.2689 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.2689 - accuracy: 0.9025 - val_loss: 0.5525 - val_accuracy: 0.7912
# Epoch 136/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.2431 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.2431 - accuracy: 0.9115 - val_loss: 0.2230 - val_accuracy: 0.9112
# Epoch 137/400
# 7/7 [==============================] - 0s 27ms/step- loss: 0.2268 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.2268 - accuracy: 0.9170 - val_loss: 0.1180 - val_accuracy: 0.9514
# Epoch 138/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.2364 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.2364 - accuracy: 0.9142 - val_loss: 0.6007 - val_accuracy: 0.8086
# Epoch 139/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.2189 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.2189 - accuracy: 0.9214 - val_loss: 0.1538 - val_accuracy: 0.9352
# Epoch 140/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.2166 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.2166 - accuracy: 0.9217 - val_loss: 0.1401 - val_accuracy: 0.9562
# Epoch 141/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.2128 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.2128 - accuracy: 0.9197 - val_loss: 0.1833 - val_accuracy: 0.9382
# Epoch 142/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.2233 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.2233 - accuracy: 0.9235 - val_loss: 0.5234 - val_accuracy: 0.8362
# Epoch 143/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.2352 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.2352 - accuracy: 0.9226 - val_loss: 0.0952 - val_accuracy: 0.9730
# Epoch 144/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.2346 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.2346 - accuracy: 0.9208 - val_loss: 0.3095 - val_accuracy: 0.8800
# Epoch 145/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.2298 - accuracy:
# 334/334 [==============================] - 27s 81ms/step - loss: 0.2298 - accuracy: 0.9235 - val_loss: 0.1057 - val_accuracy: 0.9628
# Epoch 146/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.2317 - accuracy:
# 334/334 [==============================] - 28s 82ms/step - loss: 0.2317 - accuracy: 0.9212 - val_loss: 0.1197 - val_accuracy: 0.9592
# Epoch 147/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.2460 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.2460 - accuracy: 0.9185 - val_loss: 0.1081 - val_accuracy: 0.9634
# Epoch 148/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.2160 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.2160 - accuracy: 0.9191 - val_loss: 0.0912 - val_accuracy: 0.9754
# Epoch 149/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.2161 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.2161 - accuracy: 0.9257 - val_loss: 0.2590 - val_accuracy: 0.8944
# Epoch 150/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1955 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.1955 - accuracy: 0.9313 - val_loss: 0.0861 - val_accuracy: 0.9718
# Epoch 151/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1967 - accuracy:
# 334/334 [==============================] - 27s 82ms/step - loss: 0.1967 - accuracy: 0.9301 - val_loss: 0.0864 - val_accuracy: 0.9706
# Epoch 152/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1948 - accuracy:
# 334/334 [==============================] - 30s 88ms/step - loss: 0.1948 - accuracy: 0.9317 - val_loss: 0.0764 - val_accuracy: 0.9742
# Epoch 153/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.2128 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.2128 - accuracy: 0.9287 - val_loss: 0.0819 - val_accuracy: 0.9766
# Epoch 154/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1868 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1868 - accuracy: 0.9302 - val_loss: 0.7249 - val_accuracy: 0.7882
# Epoch 155/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.2094 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.2094 - accuracy: 0.9259 - val_loss: 0.0914 - val_accuracy: 0.9682
# Epoch 156/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1795 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.1795 - accuracy: 0.9353 - val_loss: 1.2482 - val_accuracy: 0.6641
# Epoch 157/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1768 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1768 - accuracy: 0.9379 - val_loss: 0.4180 - val_accuracy: 0.8656
# Epoch 158/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.2013 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.2013 - accuracy: 0.9310 - val_loss: 0.2509 - val_accuracy: 0.9106
# Epoch 159/400
# 7/7 [==============================] - 0s 18ms/step- loss: 0.2194 - accuracy: 0.
# 334/334 [==============================] - 28s 84ms/step - loss: 0.2194 - accuracy: 0.9245 - val_loss: 0.0724 - val_accuracy: 0.9736
# Epoch 160/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.1928 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.1928 - accuracy: 0.9314 - val_loss: 0.4752 - val_accuracy: 0.8116
# Epoch 161/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.2210 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.2210 - accuracy: 0.9238 - val_loss: 0.2411 - val_accuracy: 0.9124
# Epoch 162/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.1687 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1687 - accuracy: 0.9367 - val_loss: 0.1146 - val_accuracy: 0.9496
# Epoch 163/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1636 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1636 - accuracy: 0.9362 - val_loss: 0.1956 - val_accuracy: 0.9274
# Epoch 164/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1744 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1744 - accuracy: 0.9382 - val_loss: 0.6575 - val_accuracy: 0.8116
# Epoch 165/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1574 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.1574 - accuracy: 0.9430 - val_loss: 0.1319 - val_accuracy: 0.9526
# Epoch 166/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1742 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.1742 - accuracy: 0.9371 - val_loss: 0.1113 - val_accuracy: 0.9526
# Epoch 167/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1708 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.1708 - accuracy: 0.9416 - val_loss: 0.1279 - val_accuracy: 0.9496
# Epoch 168/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.2051 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.2051 - accuracy: 0.9320 - val_loss: 0.0715 - val_accuracy: 0.9742
# Epoch 169/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1742 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1742 - accuracy: 0.9373 - val_loss: 0.1736 - val_accuracy: 0.9280
# Epoch 170/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1450 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1450 - accuracy: 0.9475 - val_loss: 0.0932 - val_accuracy: 0.9646
# Epoch 171/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1544 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1544 - accuracy: 0.9428 - val_loss: 0.2534 - val_accuracy: 0.9136
# Epoch 172/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1604 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1604 - accuracy: 0.9412 - val_loss: 0.0700 - val_accuracy: 0.9694
# Epoch 173/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.1315 - accuracy:
# 334/334 [==============================] - 30s 91ms/step - loss: 0.1315 - accuracy: 0.9487 - val_loss: 0.1240 - val_accuracy: 0.9406
# Epoch 174/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.1633 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.1633 - accuracy: 0.9445 - val_loss: 0.0615 - val_accuracy: 0.9778
# Epoch 175/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.1434 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.1434 - accuracy: 0.9460 - val_loss: 0.0676 - val_accuracy: 0.9706
# Epoch 176/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.1359 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.1359 - accuracy: 0.9515 - val_loss: 0.2041 - val_accuracy: 0.9280
# Epoch 177/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1794 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.1794 - accuracy: 0.9367 - val_loss: 0.2456 - val_accuracy: 0.9226
# Epoch 178/400
# 7/7 [==============================] - 0s 26ms/step- loss: 0.1403 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.1403 - accuracy: 0.9499 - val_loss: 0.1092 - val_accuracy: 0.9520
# Epoch 179/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1477 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.1477 - accuracy: 0.9461 - val_loss: 0.0791 - val_accuracy: 0.9664
# Epoch 180/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1393 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1393 - accuracy: 0.9488 - val_loss: 0.0649 - val_accuracy: 0.9724
# Epoch 181/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1438 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.1438 - accuracy: 0.9481 - val_loss: 0.0633 - val_accuracy: 0.9754
# Epoch 182/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1374 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1374 - accuracy: 0.9499 - val_loss: 0.0648 - val_accuracy: 0.9664
# Epoch 183/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1575 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1575 - accuracy: 0.9481 - val_loss: 0.0601 - val_accuracy: 0.9772
# Epoch 184/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1412 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.1412 - accuracy: 0.9488 - val_loss: 0.1357 - val_accuracy: 0.9358
# Epoch 185/400
# 7/7 [==============================] - 0s 28ms/step- loss: 0.1743 - accuracy
# 334/334 [==============================] - 28s 83ms/step - loss: 0.1743 - accuracy: 0.9367 - val_loss: 0.0735 - val_accuracy: 0.9676
# Epoch 186/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1447 - accuracy:
# 334/334 [==============================] - 27s 81ms/step - loss: 0.1447 - accuracy: 0.9479 - val_loss: 0.0536 - val_accuracy: 0.9790
# Epoch 187/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.1338 - accuracy:
# 334/334 [==============================] - 27s 82ms/step - loss: 0.1338 - accuracy: 0.9505 - val_loss: 0.0517 - val_accuracy: 0.9790
# Epoch 188/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1188 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1188 - accuracy: 0.9533 - val_loss: 0.0908 - val_accuracy: 0.9628
# Epoch 189/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.3863 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.3863 - accuracy: 0.9032 - val_loss: 0.3686 - val_accuracy: 0.8752
# Epoch 190/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1357 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1357 - accuracy: 0.9493 - val_loss: 0.1088 - val_accuracy: 0.9598
# Epoch 191/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1294 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.1294 - accuracy: 0.9491 - val_loss: 0.0867 - val_accuracy: 0.9634
# Epoch 192/400
# 7/7 [==============================] - 0s 26ms/step- loss: 0.1373 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1373 - accuracy: 0.9511 - val_loss: 0.0515 - val_accuracy: 0.9772
# Epoch 193/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1254 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1254 - accuracy: 0.9518 - val_loss: 0.4452 - val_accuracy: 0.8566
# Epoch 194/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1450 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1450 - accuracy: 0.9436 - val_loss: 0.5830 - val_accuracy: 0.8176
# Epoch 195/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1477 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.1477 - accuracy: 0.9503 - val_loss: 0.2054 - val_accuracy: 0.9082
# Epoch 196/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.1411 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.1411 - accuracy: 0.9476 - val_loss: 0.1101 - val_accuracy: 0.9610
# Epoch 197/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.1343 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.1343 - accuracy: 0.9491 - val_loss: 0.1329 - val_accuracy: 0.9358
# Epoch 198/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1107 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1107 - accuracy: 0.9580 - val_loss: 0.0711 - val_accuracy: 0.9688
# Epoch 199/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1175 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.1175 - accuracy: 0.9547 - val_loss: 0.0646 - val_accuracy: 0.9772
# Epoch 200/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1210 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.1210 - accuracy: 0.9548 - val_loss: 0.0914 - val_accuracy: 0.9688
# Epoch 201/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.1185 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.1185 - accuracy: 0.9574 - val_loss: 0.1247 - val_accuracy: 0.9496
# Epoch 202/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.1205 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1205 - accuracy: 0.9541 - val_loss: 0.0866 - val_accuracy: 0.9640
# Epoch 203/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1259 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.1259 - accuracy: 0.9511 - val_loss: 0.0667 - val_accuracy: 0.9700
# Epoch 204/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1119 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.1119 - accuracy: 0.9584 - val_loss: 0.2592 - val_accuracy: 0.9280
# Epoch 205/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1283 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.1283 - accuracy: 0.9521 - val_loss: 0.0519 - val_accuracy: 0.9766
# Epoch 206/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1614 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.1614 - accuracy: 0.9415 - val_loss: 0.0818 - val_accuracy: 0.9724
# Epoch 207/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.1505 - accuracy:
# 334/334 [==============================] - 30s 89ms/step - loss: 0.1505 - accuracy: 0.9442 - val_loss: 0.1030 - val_accuracy: 0.9634
# Epoch 208/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.1148 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.1148 - accuracy: 0.9538 - val_loss: 0.3530 - val_accuracy: 0.9112
# Epoch 209/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1140 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.1140 - accuracy: 0.9601 - val_loss: 0.0831 - val_accuracy: 0.9616
# Epoch 210/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.1719 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.1719 - accuracy: 0.9442 - val_loss: 0.0493 - val_accuracy: 0.9766
# Epoch 211/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.1319 - accuracy:
# ...
# 334/334 [==============================] - 29s 85ms/step - loss: 0.0707 - accuracy: 0.9679 - val_loss: 0.1172 - val_accuracy: 0.9478
# Epoch 331/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0725 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0725 - accuracy: 0.9673 - val_loss: 0.0323 - val_accuracy: 0.9784
# Epoch 332/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0667 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0667 - accuracy: 0.9682 - val_loss: 0.1149 - val_accuracy: 0.9652
# Epoch 333/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0689 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.0689 - accuracy: 0.9683 - val_loss: 0.0354 - val_accuracy: 0.9814
# Epoch 334/400
# 7/7 [==============================] - 0s 26ms/step- loss: 0.0780 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0780 - accuracy: 0.9680 - val_loss: 0.0519 - val_accuracy: 0.9700
# Epoch 335/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0733 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.0733 - accuracy: 0.9670 - val_loss: 0.0656 - val_accuracy: 0.9706
# Epoch 336/400
# 7/7 [==============================] - 0s 27ms/step- loss: 0.0695 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0695 - accuracy: 0.9680 - val_loss: 0.0522 - val_accuracy: 0.9718
# Epoch 337/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0718 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0718 - accuracy: 0.9677 - val_loss: 0.0551 - val_accuracy: 0.9700
# Epoch 338/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0848 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0848 - accuracy: 0.9650 - val_loss: 0.0370 - val_accuracy: 0.9808
# Epoch 339/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0688 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0688 - accuracy: 0.9668 - val_loss: 0.0320 - val_accuracy: 0.9790
# Epoch 340/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0754 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0754 - accuracy: 0.9655 - val_loss: 0.0362 - val_accuracy: 0.9778
# Epoch 341/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0686 - accuracy:
# 334/334 [==============================] - 30s 91ms/step - loss: 0.0686 - accuracy: 0.9713 - val_loss: 0.0311 - val_accuracy: 0.9802
# Epoch 342/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0673 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.0673 - accuracy: 0.9692 - val_loss: 0.2801 - val_accuracy: 0.8920
# Epoch 343/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0841 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0841 - accuracy: 0.9650 - val_loss: 0.3178 - val_accuracy: 0.8854
# Epoch 344/400
# 7/7 [==============================] - 0s 26ms/step- loss: 0.0740 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.0740 - accuracy: 0.9662 - val_loss: 0.0447 - val_accuracy: 0.9748
# Epoch 345/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0796 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0796 - accuracy: 0.9650 - val_loss: 0.0501 - val_accuracy: 0.9676
# Epoch 346/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0622 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0622 - accuracy: 0.9713 - val_loss: 0.4612 - val_accuracy: 0.9022
# Epoch 347/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0669 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.0669 - accuracy: 0.9670 - val_loss: 0.0331 - val_accuracy: 0.9802
# Epoch 348/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0716 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0716 - accuracy: 0.9670 - val_loss: 0.1003 - val_accuracy: 0.9622
# Epoch 349/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0751 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0751 - accuracy: 0.9688 - val_loss: 0.0784 - val_accuracy: 0.9538
# Epoch 350/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.0646 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0646 - accuracy: 0.9715 - val_loss: 0.0484 - val_accuracy: 0.9742
# Epoch 351/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0781 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.0781 - accuracy: 0.9680 - val_loss: 0.0366 - val_accuracy: 0.9802
# Epoch 352/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0633 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0633 - accuracy: 0.9676 - val_loss: 0.1001 - val_accuracy: 0.9556
# Epoch 353/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0705 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0705 - accuracy: 0.9680 - val_loss: 0.1221 - val_accuracy: 0.9550
# Epoch 354/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0582 - accuracy:
# 334/334 [==============================] - 30s 89ms/step - loss: 0.0582 - accuracy: 0.9724 - val_loss: 0.0559 - val_accuracy: 0.9718
# Epoch 355/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0648 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0648 - accuracy: 0.9712 - val_loss: 0.0345 - val_accuracy: 0.9790
# Epoch 356/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0648 - accuracy:
# 334/334 [==============================] - 30s 90ms/step - loss: 0.0648 - accuracy: 0.9697 - val_loss: 0.0340 - val_accuracy: 0.9790
# Epoch 357/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0625 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0625 - accuracy: 0.9715 - val_loss: 0.0308 - val_accuracy: 0.9784
# Epoch 358/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0648 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.0648 - accuracy: 0.9695 - val_loss: 0.0544 - val_accuracy: 0.9784
# Epoch 359/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0660 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0660 - accuracy: 0.9677 - val_loss: 0.0372 - val_accuracy: 0.9790
# Epoch 360/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0639 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.0639 - accuracy: 0.9689 - val_loss: 0.0337 - val_accuracy: 0.9802
# Epoch 361/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0675 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0675 - accuracy: 0.9686 - val_loss: 0.0448 - val_accuracy: 0.9724
# Epoch 362/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0692 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0692 - accuracy: 0.9679 - val_loss: 0.0453 - val_accuracy: 0.9736
# Epoch 363/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0645 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0645 - accuracy: 0.9733 - val_loss: 0.0567 - val_accuracy: 0.9760
# Epoch 364/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0797 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0797 - accuracy: 0.9677 - val_loss: 0.0745 - val_accuracy: 0.9610
# Epoch 365/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0637 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0637 - accuracy: 0.9710 - val_loss: 0.1293 - val_accuracy: 0.9460
# Epoch 366/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0611 - accuracy:
# 334/334 [==============================] - 30s 89ms/step - loss: 0.0611 - accuracy: 0.9706 - val_loss: 0.3340 - val_accuracy: 0.9022
# Epoch 367/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0734 - accuracy:
# 334/334 [==============================] - 27s 82ms/step - loss: 0.0734 - accuracy: 0.9680 - val_loss: 0.0584 - val_accuracy: 0.9688
# Epoch 368/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0637 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0637 - accuracy: 0.9728 - val_loss: 0.0339 - val_accuracy: 0.9784
# Epoch 369/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0612 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.0612 - accuracy: 0.9709 - val_loss: 0.0807 - val_accuracy: 0.9676
# Epoch 370/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0697 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.0697 - accuracy: 0.9713 - val_loss: 0.3571 - val_accuracy: 0.9160
# Epoch 371/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0843 - accuracy:
# 334/334 [==============================] - 28s 83ms/step - loss: 0.0843 - accuracy: 0.9673 - val_loss: 0.6123 - val_accuracy: 0.8254
# Epoch 372/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0917 - accuracy:
# 334/334 [==============================] - 30s 90ms/step - loss: 0.0917 - accuracy: 0.9641 - val_loss: 0.0351 - val_accuracy: 0.9796
# Epoch 373/400
# 7/7 [==============================] - 0s 26ms/step- loss: 0.0635 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.0635 - accuracy: 0.9698 - val_loss: 0.0343 - val_accuracy: 0.9784
# Epoch 374/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0636 - accuracy:
# 334/334 [==============================] - 28s 84ms/step - loss: 0.0636 - accuracy: 0.9700 - val_loss: 0.1056 - val_accuracy: 0.9610
# Epoch 375/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0539 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0539 - accuracy: 0.9730 - val_loss: 0.1397 - val_accuracy: 0.9460
# Epoch 376/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0611 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0611 - accuracy: 0.9697 - val_loss: 0.0467 - val_accuracy: 0.9796
# Epoch 377/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0637 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.0637 - accuracy: 0.9712 - val_loss: 0.0326 - val_accuracy: 0.9796
# Epoch 378/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0685 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0685 - accuracy: 0.9695 - val_loss: 0.0572 - val_accuracy: 0.9706
# Epoch 379/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0649 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0649 - accuracy: 0.9712 - val_loss: 0.0383 - val_accuracy: 0.9760
# Epoch 380/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0780 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.0780 - accuracy: 0.9691 - val_loss: 0.1131 - val_accuracy: 0.9640
# Epoch 381/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0722 - accuracy:
# 334/334 [==============================] - 30s 88ms/step - loss: 0.0722 - accuracy: 0.9685 - val_loss: 0.2962 - val_accuracy: 0.9220
# Epoch 382/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0617 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0617 - accuracy: 0.9689 - val_loss: 0.1308 - val_accuracy: 0.9436
# Epoch 383/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0699 - accuracy:
# 334/334 [==============================] - 30s 91ms/step - loss: 0.0699 - accuracy: 0.9689 - val_loss: 0.0829 - val_accuracy: 0.9610
# Epoch 384/400
# 7/7 [==============================] - 0s 19ms/step- loss: 0.0588 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0588 - accuracy: 0.9730 - val_loss: 0.0963 - val_accuracy: 0.9658
# Epoch 385/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0630 - accuracy:
# 334/334 [==============================] - 29s 87ms/step - loss: 0.0630 - accuracy: 0.9698 - val_loss: 0.0358 - val_accuracy: 0.9766
# Epoch 386/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.0695 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.0695 - accuracy: 0.9671 - val_loss: 0.0795 - val_accuracy: 0.9598
# Epoch 387/400
# 7/7 [==============================] - 0s 28ms/step- loss: 0.0625 - accuracy:
# 334/334 [==============================] - 32s 95ms/step - loss: 0.0625 - accuracy: 0.9727 - val_loss: 0.0317 - val_accuracy: 0.9784
# Epoch 388/400
# 7/7 [==============================] - 0s 23ms/step- loss: 0.0650 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0650 - accuracy: 0.9716 - val_loss: 0.0383 - val_accuracy: 0.9754
# Epoch 389/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0633 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.0633 - accuracy: 0.9680 - val_loss: 0.0309 - val_accuracy: 0.9832
# Epoch 390/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0728 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0728 - accuracy: 0.9703 - val_loss: 0.0307 - val_accuracy: 0.9790
# Epoch 391/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0743 - accuracy:
# 334/334 [==============================] - 30s 90ms/step - loss: 0.0743 - accuracy: 0.9656 - val_loss: 0.0756 - val_accuracy: 0.9706
# Epoch 392/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0630 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.0630 - accuracy: 0.9700 - val_loss: 0.0310 - val_accuracy: 0.9778
# Epoch 393/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0603 - accuracy:
# 334/334 [==============================] - 29s 85ms/step - loss: 0.0603 - accuracy: 0.9718 - val_loss: 0.0326 - val_accuracy: 0.9784
# Epoch 394/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0643 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.0643 - accuracy: 0.9716 - val_loss: 0.1277 - val_accuracy: 0.9418
# Epoch 395/400
# 7/7 [==============================] - 0s 20ms/step- loss: 0.0943 - accuracy:
# 334/334 [==============================] - 29s 86ms/step - loss: 0.0943 - accuracy: 0.9617 - val_loss: 0.0518 - val_accuracy: 0.9730
# Epoch 396/400
# 7/7 [==============================] - 0s 21ms/step- loss: 0.0578 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0578 - accuracy: 0.9694 - val_loss: 0.0586 - val_accuracy: 0.9718
# Epoch 397/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0631 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0631 - accuracy: 0.9704 - val_loss: 0.1055 - val_accuracy: 0.9490
# Epoch 398/400
# 7/7 [==============================] - 0s 22ms/step- loss: 0.0645 - accuracy:
# 334/334 [==============================] - 30s 91ms/step - loss: 0.0645 - accuracy: 0.9689 - val_loss: 0.0294 - val_accuracy: 0.9814
# Epoch 399/400
# 7/7 [==============================] - 0s 25ms/step- loss: 0.0545 - accuracy:
# 334/334 [==============================] - 29s 88ms/step - loss: 0.0545 - accuracy: 0.9718 - val_loss: 0.4001 - val_accuracy: 0.8800
# Epoch 400/400
# 7/7 [==============================] - 0s 24ms/step- loss: 0.0656 - accuracy:
# 334/334 [==============================] - 28s 85ms/step - loss: 0.0656 - accuracy: 0.9677 - val_loss: 0.0726 - val_accuracy: 0.9700
# Accuracy: 24.50%

# %%
y_pred = model.predict(X_test_def)
#y_pred1=y_pred[:,-1]
y_pred2=np.argmax(y_pred,axis=1)
#y_pred2=np.where(y_pred>0,1,0)
#y_pred2=y_pred2[:,-1]
y_test_def2=np.argmax(y_test_def,axis=1)
#y_test_def2=np.where(y_test_def>0,1,0)
print(y_pred.shape)
print(y_pred2.shape)
print(y_test_def2.shape)
#print(y_test_def[25])
# Out:
# 7/7 [==============================] - 0s 32ms/step
# (200, 5)
# (200,)
# (200,)

# %%
#docs_infra: no_execute
classes = [0, 1, 2, 3, 4]
classes = [0, 1]
cm=confusion_matrix(y_test_def2, y_pred2,labels=classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
# model.save('modelos/modelote1203_200')  # creates a HDF5 file 'my_model.h5'

# %%
model.save('modelos/modelo_perfecto_{}_{}'.format(experimento,datetime.datetime.now().strftime("%Y%m%d-%H%M%S")))
# Out:
# INFO:tensorflow:Assets written to: modelos/modelo_perfecto_LOMOS_P2_y_P1_GRU2_2_clases_50_dense_onehot_50_loss_categorical_crossentropy_lr_0.001_algoritmo_RMSprop_20240513-131448/assets
# INFO:tensorflow:Assets written to: modelos/modelo_perfecto_LOMOS_P2_y_P1_GRU2_2_clases_50_dense_onehot_50_loss_categorical_crossentropy_lr_0.001_algoritmo_RMSprop_20240513-131448/assets

# %%
from scipy import stats
y_pred = model.predict(X_test_def)
#y_pred2 = scaler_out.inverse_transform(y_pred) #valor denormalizado

#y_pred1=y_pred[:,-1]
y_pred2=np.argmax(y_pred,axis=1)
n = len(y_pred2)
reshaped = y_pred2[:n//4*4].reshape(-1, 4)
mean_values = reshaped.mean(axis=1)

mean_values = np.round(mean_values)
mean_values = np.clip(mean_values, 0, 4)
mean_values = mean_values.astype(int)
print(mean_values)

mode_values = stats.mode(reshaped, axis=1)[0]
print(mode_values)

# Convierte los arrays a DataFrames
mean_df = pd.DataFrame(mean_values, columns=['mean'])
mode_df = pd.DataFrame(mode_values, columns=['mode'])

# Guarda los DataFrames en archivos Excel
mean_df.to_excel("clasificacion_P1_mean_best7.xlsx", index=False)
mode_df.to_excel("clasificacion_P1_mode_best7.xlsx", index=False)
# Out:
# 7/7 [==============================] - 0s 20ms/step
# [2 2 0 2 1 2 0 2 2 2 0 1 2 2 1 1 2 2 2 0 0 2 4 2 1 1 2 2 3 2 4 0 1 1 2 4 2
#  1 2 4 2 1 2 3 2 0 2 0 2 2]
# [0 0 0 3 0 2 0 2 2 2 0 0 2 0 0 0 0 4 2 0 0 2 4 0 0 0 0 0 4 2 4 0 0 0 2 4 0
#  0 0 4 0 0 2 4 2 0 0 0 0 2]

# %%
print(y_pred2)
# Out:
# [0 2 0 4 4 0 2 0 2 0 0 0 0 3 3 2 1 0 0 2 0 2 2 3 0 2 0 0 2 0 2 2 0 2 4 2 2
#  0 2 2 0 0 0 0 3 0 0 0 2 2 2 0 0 0 2 4 2 3 0 0 2 2 0 0 3 4 0 2 0 4 4 2 2 2
#  2 3 0 0 2 0 2 0 0 0 3 0 2 2 4 4 4 2 4 0 0 3 2 3 0 0 2 0 2 0 1 0 2 4 4 0 2
#  3 4 3 2 4 2 3 2 0 2 4 4 4 0 0 0 2 0 0 0 3 2 2 0 0 2 2 2 0 4 4 4 2 4 0 2 3
#  2 0 2 0 3 4 2 0 4 4 4 4 3 0 0 3 0 0 3 2 3 2 2 2 2 1 4 4 2 2 2 2 0 0 2 0 4
#  0 0 2 0 1 0 0 2 0 4 0 2 4 0 2]
