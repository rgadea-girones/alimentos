# %% [markdown]
# # Simple CNN for PETALO
#
# Esta red la vamos a utilizar para obtener el radio

# %%
import numpy as np
#np.random.seed(1337)  # for reproducibility
from time import time
from datetime import datetime
from sklearn import preprocessing
import sys

sys.path.append("/home/rgadea/lmfit-py/")
sys.path.append("/home/rgadea/experimentos/viherbos/")

print(sys.path)
import json 

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# import seaborn as sns
from keras.datasets import mnist
from keras.models import Model, Sequential, load_model
from keras.layers import Input, Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D,Conv3D, MaxPooling3D, MaxPooling2D,BatchNormalization
from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras import regularizers
from keras.optimizers import Adam, Nadam, RMSprop, SGD
from math import floor
from lmfit.models import  GaussianModel
import matplotlib.pyplot as plt
# Out:
# ['/home/rgadea/anaconda3/envs/tensorflow3/lib/python36.zip', '/home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6', '/home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/lib-dynload', '', '/home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages', '/home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/IPython/extensions', '/volumedisk0/home/rgadea/.ipython', '/home/rgadea/lmfit-py/', '/home/rgadea/experimentos/viherbos/']
# Using TensorFlow backend.
# /home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from keras import backend as K
K.tensorflow_backend._get_available_gpus()
import tensorflow as tf
print(tf.__version__)
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# Out:
# 1.13.1

# %% [markdown]
# ## Vamos introducir los datos de petalo preprocesados en pyhton

# %%
filtro=2
if filtro==1:
    npzfile = np.load('../conjuntos_datos_nuevos_2020/20_12_2019_comptom_filt.npz')
    npzfile.files
    conjunto_datos_entradasA=npzfile['arr_0']
    conjunto_datos_entradasB=npzfile['arr_1']
    conjunto_datos_salidas=npzfile['arr_2']
else:
    if filtro==2:
        npzfile = np.load('../conjuntos_datos_nuevos_2020/26_12_2019_filt4.npz')
        npzfile.files
        conjunto_datos_entradasA=npzfile['arr_0']
        conjunto_datos_entradasB=npzfile['arr_1']
        conjunto_datos_salidas=npzfile['arr_2']
    else:
        npzfile = np.load('../conjuntos_datos_nuevos_2020/11_12_2019.npz')
        npzfile.files
        entradas_sensorsA1=npzfile['arr_0']
        entradas_sensorsB1=npzfile['arr_1']
        coordenadas1=npzfile['arr_2']
        entradas_sensorsA2=npzfile['arr_3']
        entradas_sensorsB2=npzfile['arr_4']
        coordenadas2=npzfile['arr_5']
        conjunto_datos_entradasA=np.concatenate((entradas_sensorsA1,entradas_sensorsA2),axis=0)
        conjunto_datos_entradasB=np.concatenate((entradas_sensorsB1,entradas_sensorsB2),axis=0)
        conjunto_datos_salidas=np.concatenate((coordenadas1,coordenadas2),axis=0)


print('conjunto_datos_entradas A shape:', conjunto_datos_entradasA.shape)
print('conjunto_datos_entradas B shape:', conjunto_datos_entradasB.shape)
print('conjunto_datos_salidas shape:', conjunto_datos_salidas.shape)
# Out:
# conjunto_datos_entradas A shape: (29714, 20, 175)
# conjunto_datos_entradas B shape: (29714, 20, 175)
# conjunto_datos_salidas shape: (29714, 3)

# %%
for i in range(1,11):
    idea=np.random.randint(1,conjunto_datos_entradasB.shape[0])
    plt.imshow(conjunto_datos_entradasB[idea], cmap='viridis')
    plt.show()
    print(conjunto_datos_salidas[idea,0:3])
# Out:
# [165.33811214  34.3858985  -30.20196724]
# [166.88022172  19.92617366 -31.97192192]
# [180.12032466 227.22468343  63.9383316 ]
# [184.263692   305.1280413   63.42424393]
# [182.10358067 171.71912943 -23.00575066]
# [174.88562543  27.95424284 -11.68170547]
# [169.26745089 351.99283089 -16.77956772]
# [170.22997539  25.34375899  44.01642609]
# [170.41434878 187.37426423  15.67512226]
# [177.15311646 269.87273443  32.33403015]

# %% [markdown]
# ## Network parameters:

# %%
batch_size = 250
nb_classes = 10
nb_epoch = 1000

# input image dimensions
img_rows, img_cols = 20, 41
# number of convolutional filters to use
nb_filters = 32
# size of pooling area for max pooling
pool_size = (2, 2)
# convolution kernel size
kernel_size = ( 4, 4)

# %% [markdown]
# ## Prepare data into training and test set.

# %%
muestras=conjunto_datos_entradasA.shape[0]
# veamos=idea.reshape(idea.shape[0],175, 20)


veamos2A=np.zeros([muestras,20,175])
veamos2_3A=np.zeros([muestras,20,525])
veamos2B=np.zeros([muestras,20,175])
veamos2_3B=np.zeros([muestras,20,525])
sector2A=np.zeros([muestras,20,img_cols])
sector2B=np.zeros([muestras,20,img_cols])
veamos3=np.zeros([muestras,175])
# for i in range(idea.shape[0]):
for i in range(muestras):
    veamos2A[i]=conjunto_datos_entradasA[i]
    veamos2B[i]=conjunto_datos_entradasB[i]
    veamos3[i]=np.sum(veamos2A[i], axis=0)
    indice=np.argmax(veamos3[i], axis=0)
    indice_inferior=int(indice-((img_cols-1)/2)+175)
    indice_superior=int(indice+((img_cols+1)/2)+175)
    veamos2_3A[i]=np.concatenate((veamos2A[i],veamos2A[i],veamos2A[i]),axis=1) 
    veamos2_3B[i]=np.concatenate((veamos2B[i],veamos2B[i],veamos2B[i]),axis=1) 
    sector2A[i]=veamos2_3A[i,:,indice_inferior:indice_superior]
    sector2B[i]=veamos2_3B[i,:,indice_inferior:indice_superior]

# %% [markdown]
# ## data augmentation mediante flip horizontal y vertical

# %% [markdown]
# Atencion: la z es copiada pero en realidad es incorrecta. Podemos asegurar que el radio y phi si que son las mismas; pero la z claramente al hacer un flip vertical no puede ser la misma

# %%
veamosA=np.zeros([4*muestras,20,img_cols])
veamosB=np.zeros([4*muestras,20,img_cols])
conjunto_datos_salidas_nuevo=np.zeros([4*muestras,3])
for i in range(muestras):
    veamosA[i*4]=sector2A[i]  
    caramba=np.flipud(sector2A[i]) 
    veamosA[i*4+1]=caramba  
    veamosA[i*4+2]=np.fliplr(caramba)     
    veamosA[i*4+3]=np.fliplr(sector2A[i])     
    veamosB[i*4]=sector2B[i]   
    caramba=np.flipud(sector2B[i]) 
    veamosB[i*4+1]=caramba   
    veamosB[i*4+2]=np.fliplr(caramba)  
    veamosB[i*4+3]=np.fliplr(sector2B[i])
    conjunto_datos_salidas_nuevo[i*4]=conjunto_datos_salidas[i]
    conjunto_datos_salidas_nuevo[i*4+1]=conjunto_datos_salidas[i]    
    conjunto_datos_salidas_nuevo[i*4+2]=conjunto_datos_salidas[i]  
    conjunto_datos_salidas_nuevo[i*4+3]=conjunto_datos_salidas[i]

# %%
print('sector A shape:', veamosA.shape)
conjunto_datos_nuevoA=veamosA.reshape(veamosA.shape[0], img_rows*img_cols)
print('conjunto_datos_nuevo A:', conjunto_datos_nuevoA.shape)

print('sector B shape:', veamosB.shape)
conjunto_datos_nuevoB=veamosB.reshape(veamosB.shape[0], img_rows*img_cols)
print('conjunto_datos_nuevo B:', conjunto_datos_nuevoB.shape)
print('conjunto_datos_salidas_nuevo:', conjunto_datos_salidas_nuevo.shape)
# Out:
# sector A shape: (118856, 20, 41)
# conjunto_datos_nuevo A: (118856, 820)
# sector B shape: (118856, 20, 41)
# conjunto_datos_nuevo B: (118856, 820)
# conjunto_datos_salidas_nuevo: (118856, 3)

# %%
n = 5  # how many digits we will display

fig = plt.figure(figsize=(8,20))

for i in range(n):
    # display original
    ideas=np.random.randint(1,muestras)
    ax = fig.add_subplot(n, 2, (i)*2+1)
    plt.imshow(sector2A[ideas], cmap='viridis')
    plt.viridis()

    # display reconstruction
    ax = fig.add_subplot(n, 2, (i)*2+2)
    plt.imshow(sector2B[ideas], cmap='viridis')
    plt.viridis()

plt.show()

# print(x_test[idea])
# print(decoded_imgs[idea])
# print(decoded_imgs_scaled[idea])

# %%
# convert class vectors to binary class matrices
#Y_train = np_utils.to_categorical(y_train, nb_classes)
#Y_test = np_utils.to_categorical(y_test, nb_classes)
for i in range(1,5):
    idea=np.random.randint(1,sector2B.shape[0])
    plt.imshow(sector2B[idea], cmap='viridis')
    plt.show()

# %%
numero_muestras=4*muestras
tr_size=60
val_size=20
test_size=100-val_size-tr_size
conjunto_datos_nuevo2=np.concatenate((conjunto_datos_salidas_nuevo,conjunto_datos_nuevoB), axis=1)

tamanyo_tr=floor(tr_size*numero_muestras/100)
tamanyo_val=floor(val_size*numero_muestras/100)
tamanyo_test=numero_muestras-tamanyo_tr-tamanyo_val
print(tamanyo_tr)
print(tamanyo_val)
print(tamanyo_test)


XY_test=conjunto_datos_nuevo2[tamanyo_tr+tamanyo_val:numero_muestras,:]


XY_test_bin0=XY_test[np.where((XY_test[:,0]>=164.9999) * (XY_test[:,0]<171.000))]
XY_test_bin1=XY_test[np.where((XY_test[:,0]>=171.000) * (XY_test[:,0]<177.000))]
XY_test_bin2=XY_test[np.where((XY_test[:,0]>=177.000) * (XY_test[:,0]<183.0000))]
XY_test_bin3=XY_test[np.where((XY_test[:,0]>=183.000) * (XY_test[:,0]<189.0000))]
XY_test_bin4=XY_test[np.where((XY_test[:,0]>=189.0000))]

X_train=conjunto_datos_nuevo2[:tamanyo_tr,3:]
X_val=conjunto_datos_nuevo2[tamanyo_tr:tamanyo_tr+tamanyo_val,3:]
X_test=conjunto_datos_nuevo2[tamanyo_tr+tamanyo_val:numero_muestras,3:]









X_test_bin0=XY_test_bin0[:,3:]
Y_test_bin0=XY_test_bin0[:,0]
print(X_test_bin0.shape)
X_test_bin1=XY_test_bin1[:,3:]
Y_test_bin1=XY_test_bin1[:,0]
print(X_test_bin1.shape)
X_test_bin2=XY_test_bin2[:,3:]
Y_test_bin2=XY_test_bin2[:,0]
print(X_test_bin2.shape)
X_test_bin3=XY_test_bin3[:,3:]
Y_test_bin3=XY_test_bin3[:,0]
print(X_test_bin3.shape)
X_test_bin4=XY_test_bin4[:,3:]
Y_test_bin4=XY_test_bin4[:,0]
print(X_test_bin4.shape)

Y_train=conjunto_datos_nuevo2[:tamanyo_tr,0] #elijo la coordenada radius
Y_val=conjunto_datos_nuevo2[tamanyo_tr:tamanyo_tr+tamanyo_val,0] #elijo la corrdenada radius
Y_test=conjunto_datos_nuevo2[tamanyo_tr+tamanyo_val:numero_muestras,0] #elijo la corrdenada radius
# Out:
# 71313
# 23771
# 23772
# (10668, 820)
# (5748, 820)
# (4372, 820)
# (2048, 820)
# (936, 820)

# %% [markdown]
# Vamos a normalizar las salidas por si luego nos interea

# %%
Y_total=conjunto_datos_nuevo2[:numero_muestras,0]
min_max_scaler = preprocessing.MinMaxScaler().fit(Y_total.reshape(-1, 1))

Y_train_scaled = min_max_scaler.transform(Y_train.reshape(-1, 1))
Y_val_scaled = min_max_scaler.transform(Y_val.reshape(-1, 1))
Y_test_scaled = min_max_scaler.transform(Y_test.reshape(-1, 1))

Y_test_bin4_scaled=min_max_scaler.transform(Y_test_bin4.reshape(-1, 1))
Y_test_bin3_scaled=min_max_scaler.transform(Y_test_bin3.reshape(-1, 1))
Y_test_bin2_scaled=min_max_scaler.transform(Y_test_bin2.reshape(-1, 1))
Y_test_bin1_scaled=min_max_scaler.transform(Y_test_bin1.reshape(-1, 1))
Y_test_bin0_scaled=min_max_scaler.transform(Y_test_bin0.reshape(-1, 1))

# %%
X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols,1)
X_val = X_val.reshape(X_val.shape[0], img_rows, img_cols,1)
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols,1)

X_test_bin0 = X_test_bin0.reshape(X_test_bin0.shape[0],  img_rows, img_cols,1)
X_test_bin1 = X_test_bin1.reshape(X_test_bin1.shape[0],  img_rows, img_cols,1)
X_test_bin2 = X_test_bin2.reshape(X_test_bin2.shape[0],  img_rows, img_cols,1)
X_test_bin3 = X_test_bin3.reshape(X_test_bin3.shape[0],  img_rows, img_cols,1)
X_test_bin4 = X_test_bin4.reshape(X_test_bin4.shape[0],  img_rows, img_cols,1)

input_shape = ( img_rows, img_cols,1)
#input_shape=input_shape.astype('int32')

# %%
X_train = X_train.astype('float32')
X_val= X_val.astype('float32')
X_test = X_test.astype('float32')

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_val.shape[0], 'validation samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (71313, 20, 41, 1)
# 71313 train samples
# 23771 validation samples
# 23772 test samples

# %% [markdown]
# ## Data augmentation

# %%
datagen = ImageDataGenerator(horizontal_flip=True,
                            vertical_flip=True)

# %%
# kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01))

# %%
use_regularizer = True
my_regularizer = None
# my_epochs = 50
# hidden_size=320
features_path = 'simple_autoe_features.pickle'
labels_path = 'simple_autoe_labels.pickle'

if use_regularizer:
    # add a sparsity constraint on the encoded representations
    # note use of 10e-5 leads to blurred results
    my_regularizer = regularizers.l1(0.00001)
    # and a larger number of epochs as the added regularization the model
    # is less likely to overfit and can be trained longer
    my_epochs = 100
    features_path = 'sparse_autoe_features.pickle'
    labels_path = 'sparse_autoe_labels.pickle'

# %% [markdown]
# ## Build the CNN.

# %%
model = Sequential()

model.add(Conv2D(16, kernel_size=kernel_size,
                        padding='same',
                        activity_regularizer=my_regularizer,
                        data_format='channels_last',
                        input_shape=(img_rows,img_cols,1)))
model.add(BatchNormalization(momentum=0.6))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=pool_size))

model.add(Conv2D(16, kernel_size,  kernel_regularizer=my_regularizer, padding='same'))
model.add(BatchNormalization(momentum=0.6))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=pool_size))

model.add(Conv2D(32, kernel_size,  kernel_regularizer=my_regularizer, padding='same'))
model.add(BatchNormalization(momentum=0.6))
model.add(Activation('relu'))

model.add(MaxPooling2D(pool_size=pool_size))

model.add(Conv2D(32, kernel_size,  kernel_regularizer=my_regularizer, padding='same'))

model.add(Activation('relu'))
model.add(BatchNormalization(momentum=0.6))

model.add(Conv2D(64, kernel_size, kernel_regularizer=my_regularizer, padding='same'))

model.add(Activation('relu'))
model.add(BatchNormalization(momentum=0.6))

model.add(Conv2D(64, kernel_size, kernel_regularizer=my_regularizer, padding='same'))

model.add(Activation('relu'))
model.add(BatchNormalization(momentum=0.6))

model.add(Conv2D(128, kernel_size,kernel_regularizer=my_regularizer, padding='same'))

model.add(Activation('relu'))
model.add(BatchNormalization(momentum=0.6))

model.add(Dropout(0.2))
model.add(Flatten())
# model.add(Dense(10))
# model.add(Activation('tanh'))
model.add(Dense(1,use_bias=True, 
                kernel_regularizer=my_regularizer             
               ))


dt = datetime.now().replace(second=0, microsecond=0)
experimento="CNN_kernel_{}x{}_con_batchnormalization_sector_{}x{}x{}_elu".format(kernel_size[0],kernel_size[1],img_rows,img_cols,1)
algoritmo='Nadam'
optimizador=Nadam(beta_1=0.9, beta_2=0.999)

tensorboard=TensorBoard(log_dir="../logs/defs/{}{}{}".format(experimento,algoritmo,dt))
best_model_name='../redes_CNN_R/models_best/CNN_regression_R_{}_{}_{}_{}_{}.h5'.format(nb_epoch,batch_size,experimento,algoritmo,dt)
model_check=ModelCheckpoint(best_model_name, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)
early_stop=EarlyStopping(monitor='val_loss', min_delta=0, patience=600, verbose=1, mode='auto', baseline=None)
model.compile(loss='mean_squared_error',
              optimizer=optimizador)
# Out:
# WARNING:tensorflow:From /home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# Show a summary of the model parameters.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 20, 41, 16)        272
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 20, 41, 16)        64
# _________________________________________________________________
# activation_1 (Activation)    (None, 20, 41, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 20, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 20, 16)        4112
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 10, 20, 16)        64
# _________________________________________________________________
# activation_2 (Activation)    (None, 10, 20, 16)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 10, 16)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 10, 32)         8224
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 5, 10, 32)         128
# _________________________________________________________________
# activation_3 (Activation)    (None, 5, 10, 32)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 5, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 5, 32)          16416
# _________________________________________________________________
# activation_4 (Activation)    (None, 2, 5, 32)          0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 5, 32)          128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 5, 64)          32832
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 5, 64)          0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 5, 64)          256
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2, 5, 64)          65600
# _________________________________________________________________
# activation_6 (Activation)    (None, 2, 5, 64)          0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 2, 5, 64)          256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 5, 128)         131200
# _________________________________________________________________
# activation_7 (Activation)    (None, 2, 5, 128)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 2, 5, 128)         512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2, 5, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1281
# =================================================================
# Total params: 261,345
# Trainable params: 260,641
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# And now train the model and evaluate on the test set.

# %%
history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch,
          verbose=1, validation_data=(X_val, Y_val),
                     callbacks=[tensorboard,model_check,early_stop])
# Out:
# WARNING:tensorflow:From /home/rgadea/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 71313 samples, validate on 23771 samples
# Epoch 1/1000
# 71313/71313 [==============================] - 10s 137us/step - loss: 1509.4168 - val_loss: 14.7511
#
# Epoch 00001: val_loss improved from inf to 14.75108, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 2/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 18.3928 - val_loss: 10.5194
#
# Epoch 00002: val_loss improved from 14.75108 to 10.51938, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 3/1000
# 71313/71313 [==============================] - 7s 94us/step - loss: 16.2215 - val_loss: 9.3004
#
# Epoch 00003: val_loss improved from 10.51938 to 9.30040, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 4/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 15.0466 - val_loss: 10.8676
#
# Epoch 00004: val_loss did not improve from 9.30040
# Epoch 5/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 14.4616 - val_loss: 9.6526
#
# Epoch 00005: val_loss did not improve from 9.30040
# Epoch 6/1000
# 71313/71313 [==============================] - 7s 92us/step - loss: 14.1094 - val_loss: 11.7422
#
# Epoch 00006: val_loss did not improve from 9.30040
# Epoch 7/1000
# 71313/71313 [==============================] - 7s 94us/step - loss: 13.6988 - val_loss: 7.9930
#
# Epoch 00007: val_loss improved from 9.30040 to 7.99299, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 8/1000
# 71313/71313 [==============================] - 7s 91us/step - loss: 13.5738 - val_loss: 8.9496
#
# Epoch 00008: val_loss did not improve from 7.99299
# Epoch 9/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 13.5741 - val_loss: 6.7936
#
# Epoch 00009: val_loss improved from 7.99299 to 6.79358, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 10/1000
# 71313/71313 [==============================] - 7s 94us/step - loss: 13.1986 - val_loss: 10.4071
#
# Epoch 00010: val_loss did not improve from 6.79358
# Epoch 11/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 13.0297 - val_loss: 6.5098
#
# Epoch 00011: val_loss improved from 6.79358 to 6.50983, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 12/1000
# 71313/71313 [==============================] - 7s 95us/step - loss: 12.8978 - val_loss: 6.5317
#
# Epoch 00012: val_loss did not improve from 6.50983
# Epoch 13/1000
# 71313/71313 [==============================] - 7s 92us/step - loss: 12.7935 - val_loss: 7.1084
#
# Epoch 00013: val_loss did not improve from 6.50983
# Epoch 14/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 12.8773 - val_loss: 6.5056
#
# Epoch 00014: val_loss improved from 6.50983 to 6.50556, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 15/1000
# 71313/71313 [==============================] - 7s 96us/step - loss: 12.6265 - val_loss: 6.9432
#
# Epoch 00015: val_loss did not improve from 6.50556
# Epoch 16/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 12.5075 - val_loss: 8.1897
#
# Epoch 00016: val_loss did not improve from 6.50556
# Epoch 17/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 12.6599 - val_loss: 6.8733
#
# Epoch 00017: val_loss did not improve from 6.50556
# Epoch 18/1000
# 71313/71313 [==============================] - 7s 92us/step - loss: 12.5764 - val_loss: 15.1955
#
# Epoch 00018: val_loss did not improve from 6.50556
# Epoch 19/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 12.6639 - val_loss: 6.6048
#
# Epoch 00019: val_loss did not improve from 6.50556
# Epoch 20/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 12.3474 - val_loss: 6.6386
#
# Epoch 00020: val_loss did not improve from 6.50556
# Epoch 21/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 12.2190 - val_loss: 5.7275
#
# Epoch 00021: val_loss improved from 6.50556 to 5.72749, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 22/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 12.2059 - val_loss: 6.8558
#
# Epoch 00022: val_loss did not improve from 5.72749
# Epoch 23/1000
# 71313/71313 [==============================] - 7s 95us/step - loss: 12.2459 - val_loss: 5.9482
#
# Epoch 00023: val_loss did not improve from 5.72749
# Epoch 24/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 12.2810 - val_loss: 9.0596
#
# Epoch 00024: val_loss did not improve from 5.72749
# Epoch 25/1000
# 71313/71313 [==============================] - 7s 92us/step - loss: 12.0180 - val_loss: 6.9382
#
# Epoch 00025: val_loss did not improve from 5.72749
# Epoch 26/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 11.9872 - val_loss: 6.3240
#
# Epoch 00026: val_loss did not improve from 5.72749
# Epoch 27/1000
# 71313/71313 [==============================] - 7s 91us/step - loss: 12.1288 - val_loss: 7.8421
#
# Epoch 00027: val_loss did not improve from 5.72749
# Epoch 28/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 12.0491 - val_loss: 6.6792
#
# Epoch 00028: val_loss did not improve from 5.72749
# Epoch 29/1000
# 71313/71313 [==============================] - 7s 91us/step - loss: 12.0307 - val_loss: 9.7809
#
# Epoch 00029: val_loss did not improve from 5.72749
# Epoch 30/1000
# 71313/71313 [==============================] - 7s 91us/step - loss: 11.9278 - val_loss: 14.1182
#
# Epoch 00030: val_loss did not improve from 5.72749
# Epoch 31/1000
# 71313/71313 [==============================] - 7s 92us/step - loss: 11.8643 - val_loss: 7.0368
#
# Epoch 00031: val_loss did not improve from 5.72749
# Epoch 32/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 11.9106 - val_loss: 6.3192
#
# Epoch 00032: val_loss did not improve from 5.72749
# Epoch 33/1000
# 71313/71313 [==============================] - 7s 95us/step - loss: 11.7618 - val_loss: 6.5221
#
# Epoch 00033: val_loss did not improve from 5.72749
# Epoch 34/1000
# 71313/71313 [==============================] - 7s 95us/step - loss: 11.6599 - val_loss: 8.6855
#
# Epoch 00034: val_loss did not improve from 5.72749
# Epoch 35/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 11.5818 - val_loss: 6.4164
#
# Epoch 00035: val_loss did not improve from 5.72749
# Epoch 36/1000
# 71313/71313 [==============================] - 7s 92us/step - loss: 11.7139 - val_loss: 5.5638
#
# Epoch 00036: val_loss improved from 5.72749 to 5.56382, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 37/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 11.7465 - val_loss: 9.3230
#
# Epoch 00037: val_loss did not improve from 5.56382
# Epoch 38/1000
# 71313/71313 [==============================] - 7s 95us/step - loss: 11.5498 - val_loss: 6.0274
#
# Epoch 00038: val_loss did not improve from 5.56382
# Epoch 39/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 11.6235 - val_loss: 5.8101
#
# Epoch 00039: val_loss did not improve from 5.56382
# Epoch 40/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 11.5020 - val_loss: 9.0371
#
# Epoch 00040: val_loss did not improve from 5.56382
# Epoch 41/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 11.4004 - val_loss: 11.6706
#
# Epoch 00041: val_loss did not improve from 5.56382
# Epoch 42/1000
# 71313/71313 [==============================] - 7s 94us/step - loss: 11.5152 - val_loss: 6.6579
#
# Epoch 00042: val_loss did not improve from 5.56382
# Epoch 43/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 11.3712 - val_loss: 6.5654
#
# Epoch 00043: val_loss did not improve from 5.56382
# Epoch 44/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 11.4277 - val_loss: 5.5754
#
# Epoch 00044: val_loss did not improve from 5.56382
# Epoch 45/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 11.3935 - val_loss: 5.6768
#
# Epoch 00045: val_loss did not improve from 5.56382
# Epoch 46/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 11.3879 - val_loss: 6.3681
#
# Epoch 00046: val_loss did not improve from 5.56382
# Epoch 47/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 11.2224 - val_loss: 7.1093
#
# Epoch 00047: val_loss did not improve from 5.56382
# Epoch 48/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 11.4666 - val_loss: 6.3170
#
# Epoch 00048: val_loss did not improve from 5.56382
# Epoch 49/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 11.2625 - val_loss: 5.9069
#
# Epoch 00049: val_loss did not improve from 5.56382
# Epoch 50/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 11.2208 - val_loss: 5.5434
#
# Epoch 00050: val_loss improved from 5.56382 to 5.54344, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 51/1000
# 71313/71313 [==============================] - 7s 92us/step - loss: 11.1996 - val_loss: 6.0376
#
# Epoch 00051: val_loss did not improve from 5.54344
# Epoch 52/1000
# 71313/71313 [==============================] - 7s 95us/step - loss: 11.2516 - val_loss: 6.9012
#
# Epoch 00052: val_loss did not improve from 5.54344
# Epoch 53/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 11.1337 - val_loss: 6.1477
#
# Epoch 00053: val_loss did not improve from 5.54344
# Epoch 54/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 11.0995 - val_loss: 5.9102
#
# Epoch 00054: val_loss did not improve from 5.54344
# Epoch 55/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 11.2020 - val_loss: 9.9347
#
# Epoch 00055: val_loss did not improve from 5.54344
# Epoch 56/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 11.2066 - val_loss: 5.5155
#
# Epoch 00056: val_loss improved from 5.54344 to 5.51555, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 57/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 10.9869 - val_loss: 5.6483
#
# Epoch 00057: val_loss did not improve from 5.51555
# Epoch 58/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 11.0431 - val_loss: 6.9186
#
# Epoch 00058: val_loss did not improve from 5.51555
# Epoch 59/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 10.9889 - val_loss: 6.7342
#
# Epoch 00059: val_loss did not improve from 5.51555
# Epoch 60/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 10.9760 - val_loss: 5.6919
#
# Epoch 00060: val_loss did not improve from 5.51555
# Epoch 61/1000
# 71313/71313 [==============================] - 7s 91us/step - loss: 10.9551 - val_loss: 7.3074
#
# Epoch 00061: val_loss did not improve from 5.51555
# Epoch 62/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 10.8855 - val_loss: 5.4372
#
# Epoch 00062: val_loss improved from 5.51555 to 5.43719, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 63/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 10.9082 - val_loss: 5.7945
#
# Epoch 00063: val_loss did not improve from 5.43719
# Epoch 64/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 10.6959 - val_loss: 7.1198
#
# Epoch 00064: val_loss did not improve from 5.43719
# Epoch 65/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 10.8524 - val_loss: 9.3833
#
# Epoch 00065: val_loss did not improve from 5.43719
# Epoch 66/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 10.8430 - val_loss: 5.8982
#
# Epoch 00066: val_loss did not improve from 5.43719
# Epoch 67/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 10.8666 - val_loss: 5.5500
#
# Epoch 00067: val_loss did not improve from 5.43719
# Epoch 68/1000
# 71313/71313 [==============================] - 6s 82us/step - loss: 10.6499 - val_loss: 7.2569
#
# Epoch 00068: val_loss did not improve from 5.43719
# Epoch 69/1000
# 71313/71313 [==============================] - 6s 78us/step - loss: 10.6279 - val_loss: 7.5754
#
# Epoch 00069: val_loss did not improve from 5.43719
# Epoch 70/1000
# 71313/71313 [==============================] - 6s 81us/step - loss: 10.6675 - val_loss: 5.6616
#
# Epoch 00070: val_loss did not improve from 5.43719
# Epoch 71/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 10.5295 - val_loss: 5.7677
#
# Epoch 00071: val_loss did not improve from 5.43719
# Epoch 72/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 10.6970 - val_loss: 6.1959
#
# Epoch 00072: val_loss did not improve from 5.43719
# Epoch 73/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 10.6596 - val_loss: 5.4879
#
# Epoch 00073: val_loss did not improve from 5.43719
# Epoch 74/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 10.5677 - val_loss: 5.7095
#
# Epoch 00074: val_loss did not improve from 5.43719
# Epoch 75/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 10.4163 - val_loss: 5.7322
#
# Epoch 00075: val_loss did not improve from 5.43719
# Epoch 76/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 10.3836 - val_loss: 6.3543
#
# Epoch 00076: val_loss did not improve from 5.43719
# Epoch 77/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 10.4257 - val_loss: 5.3630
#
# Epoch 00077: val_loss improved from 5.43719 to 5.36303, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 78/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 10.4648 - val_loss: 5.6371
#
# Epoch 00078: val_loss did not improve from 5.36303
# Epoch 79/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 10.4458 - val_loss: 5.8084
#
# Epoch 00079: val_loss did not improve from 5.36303
# Epoch 80/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 10.3843 - val_loss: 5.4361
#
# Epoch 00080: val_loss did not improve from 5.36303
# Epoch 81/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 10.2544 - val_loss: 7.7102
#
# Epoch 00081: val_loss did not improve from 5.36303
# Epoch 82/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 10.4009 - val_loss: 7.3067
#
# Epoch 00082: val_loss did not improve from 5.36303
# Epoch 83/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 10.3323 - val_loss: 5.4645
#
# Epoch 00083: val_loss did not improve from 5.36303
# Epoch 84/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 10.3220 - val_loss: 5.4032
#
# Epoch 00084: val_loss did not improve from 5.36303
# Epoch 85/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 10.2705 - val_loss: 5.3138
#
# Epoch 00085: val_loss improved from 5.36303 to 5.31382, saving model to ../redes_CNN_R/models_best/CNN_regression_R_1000_250_CNN_kernel_4x4_con_batchnormalization_sector_20x41x1_elu_Nadam_2019-12-30 10:17:00.h5
# Epoch 86/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 10.3139 - val_loss: 5.5847
#
# Epoch 00086: val_loss did not improve from 5.31382
# Epoch 87/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 10.2725 - val_loss: 5.6174
#
# Epoch 00087: val_loss did not improve from 5.31382
# Epoch 88/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 10.0837 - val_loss: 5.9922
#
# Epoch 00088: val_loss did not improve from 5.31382
# Epoch 89/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 10.1520 - val_loss: 5.7756
#
# Epoch 00089: val_loss did not improve from 5.31382
# Epoch 90/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 10.0133 - val_loss: 5.5533
#
# Epoch 00090: val_loss did not improve from 5.31382
# Epoch 91/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 10.0653 - val_loss: 5.6609
#
# Epoch 00091: val_loss did not improve from 5.31382
# Epoch 92/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 10.0606 - val_loss: 5.7092
#
# Epoch 00092: val_loss did not improve from 5.31382
# Epoch 93/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 10.1561 - val_loss: 6.3848
#
# Epoch 00093: val_loss did not improve from 5.31382
# Epoch 94/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 10.0553 - val_loss: 6.3277
#
# Epoch 00094: val_loss did not improve from 5.31382
# Epoch 95/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 10.0889 - val_loss: 7.7208
#
# Epoch 00095: val_loss did not improve from 5.31382
# Epoch 96/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 10.1137 - val_loss: 5.5424
#
# Epoch 00096: val_loss did not improve from 5.31382
# Epoch 97/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 10.0262 - val_loss: 5.7144
#
# Epoch 00097: val_loss did not improve from 5.31382
# Epoch 98/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.9447 - val_loss: 6.0764
#
# Epoch 00098: val_loss did not improve from 5.31382
# Epoch 99/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.9914 - val_loss: 5.6438
#
# Epoch 00099: val_loss did not improve from 5.31382
# Epoch 100/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.9958 - val_loss: 6.9091
#
# Epoch 00100: val_loss did not improve from 5.31382
# Epoch 101/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.9035 - val_loss: 5.4869
#
# Epoch 00101: val_loss did not improve from 5.31382
# Epoch 102/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 9.9578 - val_loss: 6.2532
#
# Epoch 00102: val_loss did not improve from 5.31382
# Epoch 103/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.8985 - val_loss: 6.4118
#
# Epoch 00103: val_loss did not improve from 5.31382
# Epoch 104/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.9251 - val_loss: 6.9179
#
# Epoch 00104: val_loss did not improve from 5.31382
# Epoch 105/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.9288 - val_loss: 5.5799
#
# Epoch 00105: val_loss did not improve from 5.31382
# Epoch 106/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 9.9248 - val_loss: 5.6766
#
# Epoch 00106: val_loss did not improve from 5.31382
# Epoch 107/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 9.8638 - val_loss: 5.6099
#
# Epoch 00107: val_loss did not improve from 5.31382
# Epoch 108/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.8071 - val_loss: 5.9063
#
# Epoch 00108: val_loss did not improve from 5.31382
# Epoch 109/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 9.7858 - val_loss: 6.5232
#
# Epoch 00109: val_loss did not improve from 5.31382
# Epoch 110/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.7708 - val_loss: 5.7046
#
# Epoch 00110: val_loss did not improve from 5.31382
# Epoch 111/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.7023 - val_loss: 5.5811
#
# Epoch 00111: val_loss did not improve from 5.31382
# Epoch 112/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.8096 - val_loss: 5.8426
#
# Epoch 00112: val_loss did not improve from 5.31382
# Epoch 113/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 9.8574 - val_loss: 5.7079
#
# Epoch 00113: val_loss did not improve from 5.31382
# Epoch 114/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 9.7255 - val_loss: 7.1591
#
# Epoch 00114: val_loss did not improve from 5.31382
# Epoch 115/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.8234 - val_loss: 5.9963
#
# Epoch 00115: val_loss did not improve from 5.31382
# Epoch 116/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 9.7483 - val_loss: 5.9274
#
# Epoch 00116: val_loss did not improve from 5.31382
# Epoch 117/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.7533 - val_loss: 5.4791
#
# Epoch 00117: val_loss did not improve from 5.31382
# Epoch 118/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.6334 - val_loss: 5.8917
#
# Epoch 00118: val_loss did not improve from 5.31382
# Epoch 119/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.6194 - val_loss: 5.7870
#
# Epoch 00119: val_loss did not improve from 5.31382
# Epoch 120/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.7393 - val_loss: 5.7758
#
# Epoch 00120: val_loss did not improve from 5.31382
# Epoch 121/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.5734 - val_loss: 7.9237
#
# Epoch 00121: val_loss did not improve from 5.31382
# Epoch 122/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 9.5501 - val_loss: 5.5583
#
# Epoch 00122: val_loss did not improve from 5.31382
# Epoch 123/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.6569 - val_loss: 5.8093
#
# Epoch 00123: val_loss did not improve from 5.31382
# Epoch 124/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.6692 - val_loss: 6.1814
#
# Epoch 00124: val_loss did not improve from 5.31382
# Epoch 125/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.6440 - val_loss: 5.8561
#
# Epoch 00125: val_loss did not improve from 5.31382
# Epoch 126/1000
# 71313/71313 [==============================] - 7s 93us/step - loss: 9.5758 - val_loss: 8.6734
#
# Epoch 00126: val_loss did not improve from 5.31382
# Epoch 127/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 9.6775 - val_loss: 5.8739
#
# Epoch 00127: val_loss did not improve from 5.31382
# Epoch 128/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.6125 - val_loss: 7.2759
#
# Epoch 00128: val_loss did not improve from 5.31382
# Epoch 129/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.5400 - val_loss: 5.9747
#
# Epoch 00129: val_loss did not improve from 5.31382
# Epoch 130/1000
# 71313/71313 [==============================] - 6s 82us/step - loss: 9.6301 - val_loss: 7.5812
#
# Epoch 00130: val_loss did not improve from 5.31382
# Epoch 131/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 9.5737 - val_loss: 5.8932
#
# Epoch 00131: val_loss did not improve from 5.31382
# Epoch 132/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.4471 - val_loss: 5.5001
#
# Epoch 00132: val_loss did not improve from 5.31382
# Epoch 133/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.3721 - val_loss: 6.3733
#
# Epoch 00133: val_loss did not improve from 5.31382
# Epoch 134/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.4311 - val_loss: 5.9830
#
# Epoch 00134: val_loss did not improve from 5.31382
# Epoch 135/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 9.3571 - val_loss: 5.6517
#
# Epoch 00135: val_loss did not improve from 5.31382
# Epoch 136/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 9.4800 - val_loss: 6.0498
#
# Epoch 00136: val_loss did not improve from 5.31382
# Epoch 137/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 9.6982 - val_loss: 5.9043
#
# Epoch 00137: val_loss did not improve from 5.31382
# Epoch 138/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.4098 - val_loss: 5.9835
#
# Epoch 00138: val_loss did not improve from 5.31382
# Epoch 139/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 9.3290 - val_loss: 5.6687
#
# Epoch 00139: val_loss did not improve from 5.31382
# Epoch 140/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 9.2879 - val_loss: 6.7014
#
# Epoch 00140: val_loss did not improve from 5.31382
# Epoch 141/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 9.4047 - val_loss: 6.0894
#
# Epoch 00141: val_loss did not improve from 5.31382
# Epoch 142/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.3602 - val_loss: 5.9088
#
# Epoch 00142: val_loss did not improve from 5.31382
# Epoch 143/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 9.3780 - val_loss: 5.8576
#
# Epoch 00143: val_loss did not improve from 5.31382
# Epoch 144/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 9.2890 - val_loss: 5.8704
#
# Epoch 00144: val_loss did not improve from 5.31382
# Epoch 145/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 9.3104 - val_loss: 5.8320
#
# Epoch 00145: val_loss did not improve from 5.31382
# Epoch 146/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.3541 - val_loss: 6.1342
#
# Epoch 00146: val_loss did not improve from 5.31382
# Epoch 147/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.2427 - val_loss: 6.6721
#
# Epoch 00147: val_loss did not improve from 5.31382
# Epoch 148/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 9.2702 - val_loss: 6.3319
#
# Epoch 00148: val_loss did not improve from 5.31382
# Epoch 149/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 9.2736 - val_loss: 6.8049
#
# Epoch 00149: val_loss did not improve from 5.31382
# Epoch 150/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.2435 - val_loss: 6.1442
#
# Epoch 00150: val_loss did not improve from 5.31382
# Epoch 151/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.3266 - val_loss: 5.9842
#
# Epoch 00151: val_loss did not improve from 5.31382
# Epoch 152/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 9.2905 - val_loss: 5.9240
#
# Epoch 00152: val_loss did not improve from 5.31382
# Epoch 153/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 9.2376 - val_loss: 5.7932
#
# Epoch 00153: val_loss did not improve from 5.31382
# Epoch 154/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.1902 - val_loss: 5.9938
#
# Epoch 00154: val_loss did not improve from 5.31382
# Epoch 155/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 9.2589 - val_loss: 6.0060
#
# Epoch 00155: val_loss did not improve from 5.31382
# Epoch 156/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 9.1207 - val_loss: 5.9230
#
# Epoch 00156: val_loss did not improve from 5.31382
# Epoch 157/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.1783 - val_loss: 5.6168
#
# Epoch 00157: val_loss did not improve from 5.31382
# Epoch 158/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 9.3051 - val_loss: 5.8615
#
# Epoch 00158: val_loss did not improve from 5.31382
# Epoch 159/1000
# 71313/71313 [==============================] - 6s 91us/step - loss: 9.1408 - val_loss: 5.9881
#
# Epoch 00159: val_loss did not improve from 5.31382
# Epoch 160/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.1146 - val_loss: 6.4614
#
# Epoch 00160: val_loss did not improve from 5.31382
# Epoch 161/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.0915 - val_loss: 5.8965
#
# Epoch 00161: val_loss did not improve from 5.31382
# Epoch 162/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 9.1849 - val_loss: 6.9034
#
# Epoch 00162: val_loss did not improve from 5.31382
# Epoch 163/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.2091 - val_loss: 5.7170
#
# Epoch 00163: val_loss did not improve from 5.31382
# Epoch 164/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 9.1197 - val_loss: 6.1068
#
# Epoch 00164: val_loss did not improve from 5.31382
# Epoch 165/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.1615 - val_loss: 6.3705
#
# Epoch 00165: val_loss did not improve from 5.31382
# Epoch 166/1000
# 71313/71313 [==============================] - 6s 81us/step - loss: 9.1222 - val_loss: 6.1606
#
# Epoch 00166: val_loss did not improve from 5.31382
# Epoch 167/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 9.1223 - val_loss: 6.4637
#
# Epoch 00167: val_loss did not improve from 5.31382
# Epoch 168/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 9.0584 - val_loss: 5.8520
#
# Epoch 00168: val_loss did not improve from 5.31382
# Epoch 169/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.1435 - val_loss: 10.4474
#
# Epoch 00169: val_loss did not improve from 5.31382
# Epoch 170/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 9.0506 - val_loss: 5.8470
#
# Epoch 00170: val_loss did not improve from 5.31382
# Epoch 171/1000
# 71313/71313 [==============================] - 6s 82us/step - loss: 9.1317 - val_loss: 6.6177
#
# Epoch 00171: val_loss did not improve from 5.31382
# Epoch 172/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.0000 - val_loss: 6.3905
#
# Epoch 00172: val_loss did not improve from 5.31382
# Epoch 173/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.1316 - val_loss: 6.7346
#
# Epoch 00173: val_loss did not improve from 5.31382
# Epoch 174/1000
# 71313/71313 [==============================] - 7s 92us/step - loss: 8.9809 - val_loss: 5.8126
#
# Epoch 00174: val_loss did not improve from 5.31382
# Epoch 175/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.0553 - val_loss: 5.8623
#
# Epoch 00175: val_loss did not improve from 5.31382
# Epoch 176/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 8.9407 - val_loss: 6.7110
#
# Epoch 00176: val_loss did not improve from 5.31382
# Epoch 177/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.0141 - val_loss: 6.3684
#
# Epoch 00177: val_loss did not improve from 5.31382
# Epoch 178/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 9.0685 - val_loss: 5.7913
#
# Epoch 00178: val_loss did not improve from 5.31382
# Epoch 179/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 8.9495 - val_loss: 6.1290
#
# Epoch 00179: val_loss did not improve from 5.31382
# Epoch 180/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 9.0562 - val_loss: 5.7339
#
# Epoch 00180: val_loss did not improve from 5.31382
# Epoch 181/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.9638 - val_loss: 6.2952
#
# Epoch 00181: val_loss did not improve from 5.31382
# Epoch 182/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 8.7389 - val_loss: 6.6598
#
# Epoch 00182: val_loss did not improve from 5.31382
# Epoch 183/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.9249 - val_loss: 6.2283
#
# Epoch 00183: val_loss did not improve from 5.31382
# Epoch 184/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.9976 - val_loss: 5.8131
#
# Epoch 00184: val_loss did not improve from 5.31382
# Epoch 185/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.9077 - val_loss: 6.0663
#
# Epoch 00185: val_loss did not improve from 5.31382
# Epoch 186/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 8.9225 - val_loss: 6.3209
#
# Epoch 00186: val_loss did not improve from 5.31382
# Epoch 187/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.9543 - val_loss: 6.0494
#
# Epoch 00187: val_loss did not improve from 5.31382
# Epoch 188/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.9280 - val_loss: 5.8585
#
# Epoch 00188: val_loss did not improve from 5.31382
# Epoch 189/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.7773 - val_loss: 6.0085
#
# Epoch 00189: val_loss did not improve from 5.31382
# Epoch 190/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 8.9018 - val_loss: 6.3831
#
# Epoch 00190: val_loss did not improve from 5.31382
# Epoch 191/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 8.8846 - val_loss: 6.1241
#
# Epoch 00191: val_loss did not improve from 5.31382
# Epoch 192/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 8.8722 - val_loss: 5.8483
#
# Epoch 00192: val_loss did not improve from 5.31382
# Epoch 193/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.8749 - val_loss: 6.1962
#
# Epoch 00193: val_loss did not improve from 5.31382
# Epoch 194/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 8.7720 - val_loss: 5.8220
#
# Epoch 00194: val_loss did not improve from 5.31382
# Epoch 195/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 8.7751 - val_loss: 6.6048
#
# Epoch 00195: val_loss did not improve from 5.31382
# Epoch 196/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 8.9405 - val_loss: 6.3609
#
# Epoch 00196: val_loss did not improve from 5.31382
# Epoch 197/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 8.7428 - val_loss: 6.6167
#
# Epoch 00197: val_loss did not improve from 5.31382
# Epoch 198/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.7638 - val_loss: 6.5422
#
# Epoch 00198: val_loss did not improve from 5.31382
# Epoch 199/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.7887 - val_loss: 7.2113
#
# Epoch 00199: val_loss did not improve from 5.31382
# Epoch 200/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 8.8410 - val_loss: 6.3863
#
# Epoch 00200: val_loss did not improve from 5.31382
# Epoch 201/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.7221 - val_loss: 5.9388
#
# Epoch 00201: val_loss did not improve from 5.31382
# Epoch 202/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 8.7786 - val_loss: 5.9874
#
# Epoch 00202: val_loss did not improve from 5.31382
# Epoch 203/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 8.6504 - val_loss: 6.1025
#
# Epoch 00203: val_loss did not improve from 5.31382
# Epoch 204/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 8.7194 - val_loss: 5.8481
#
# Epoch 00204: val_loss did not improve from 5.31382
# Epoch 205/1000
# 71313/71313 [==============================] - 6s 82us/step - loss: 8.7584 - val_loss: 6.6567
#
# Epoch 00205: val_loss did not improve from 5.31382
# Epoch 206/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 8.8882 - val_loss: 6.6537
#
# Epoch 00206: val_loss did not improve from 5.31382
# Epoch 207/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 8.8038 - val_loss: 5.7511
#
# Epoch 00207: val_loss did not improve from 5.31382
# Epoch 208/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 8.6249 - val_loss: 7.5425
#
# Epoch 00208: val_loss did not improve from 5.31382
# Epoch 209/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 8.6329 - val_loss: 6.7449
#
# Epoch 00209: val_loss did not improve from 5.31382
# Epoch 210/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.7386 - val_loss: 6.1455
#
# Epoch 00210: val_loss did not improve from 5.31382
# Epoch 211/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 8.7397 - val_loss: 6.3629
#
# Epoch 00211: val_loss did not improve from 5.31382
# Epoch 212/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 8.6404 - val_loss: 6.1110
#
# Epoch 00212: val_loss did not improve from 5.31382
# Epoch 213/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 8.6282 - val_loss: 6.1488
#
# Epoch 00213: val_loss did not improve from 5.31382
# Epoch 214/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 8.6140 - val_loss: 6.1235
#
# Epoch 00214: val_loss did not improve from 5.31382
# Epoch 215/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.6022 - val_loss: 5.7988
#
# Epoch 00215: val_loss did not improve from 5.31382
# Epoch 216/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 8.5674 - val_loss: 6.0855
#
# Epoch 00216: val_loss did not improve from 5.31382
# Epoch 217/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 8.6841 - val_loss: 6.2073
#
# Epoch 00217: val_loss did not improve from 5.31382
# Epoch 218/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 8.6514 - val_loss: 6.9428
#
# Epoch 00218: val_loss did not improve from 5.31382
# Epoch 219/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.6183 - val_loss: 6.0145
#
# Epoch 00219: val_loss did not improve from 5.31382
# Epoch 220/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.5937 - val_loss: 6.0429
#
# Epoch 00220: val_loss did not improve from 5.31382
# Epoch 221/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.5831 - val_loss: 6.5145
#
# Epoch 00221: val_loss did not improve from 5.31382
# Epoch 222/1000
# 71313/71313 [==============================] - 6s 84us/step - loss: 8.5898 - val_loss: 5.9445
#
# Epoch 00222: val_loss did not improve from 5.31382
# Epoch 223/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 8.5761 - val_loss: 6.2186
#
# Epoch 00223: val_loss did not improve from 5.31382
# Epoch 224/1000
# 71313/71313 [==============================] - 6s 83us/step - loss: 8.5250 - val_loss: 6.2355
#
# Epoch 00224: val_loss did not improve from 5.31382
# Epoch 225/1000
# 71313/71313 [==============================] - 6s 89us/step - loss: 8.6343 - val_loss: 6.5084
#
# Epoch 00225: val_loss did not improve from 5.31382
# Epoch 226/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.4807 - val_loss: 6.6057
#
# Epoch 00226: val_loss did not improve from 5.31382
# Epoch 227/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 8.4510 - val_loss: 6.1397
#
# Epoch 00227: val_loss did not improve from 5.31382
# Epoch 228/1000
# 71313/71313 [==============================] - 6s 90us/step - loss: 8.4461 - val_loss: 6.1818
#
# Epoch 00228: val_loss did not improve from 5.31382
# Epoch 229/1000
# 71313/71313 [==============================] - 6s 88us/step - loss: 8.4994 - val_loss: 5.9900
#
# Epoch 00229: val_loss did not improve from 5.31382
# Epoch 230/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.4639 - val_loss: 7.8280
#
# Epoch 00230: val_loss did not improve from 5.31382
# Epoch 231/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.4749 - val_loss: 6.1663
#
# Epoch 00231: val_loss did not improve from 5.31382
# Epoch 232/1000
# 71313/71313 [==============================] - 6s 82us/step - loss: 8.4143 - val_loss: 6.4607
#
# Epoch 00232: val_loss did not improve from 5.31382
# Epoch 233/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 8.4526 - val_loss: 5.9089
#
# Epoch 00233: val_loss did not improve from 5.31382
# Epoch 234/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.4650 - val_loss: 6.4392
#
# Epoch 00234: val_loss did not improve from 5.31382
# Epoch 235/1000
# 71313/71313 [==============================] - 6s 82us/step - loss: 8.4242 - val_loss: 5.9385
#
# Epoch 00235: val_loss did not improve from 5.31382
# Epoch 236/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 8.4629 - val_loss: 6.2072
#
# Epoch 00236: val_loss did not improve from 5.31382
# Epoch 237/1000
# 71313/71313 [==============================] - 6s 85us/step - loss: 8.5082 - val_loss: 6.0733
#
# Epoch 00237: val_loss did not improve from 5.31382
# Epoch 238/1000
# 71313/71313 [==============================] - 6s 87us/step - loss: 8.4828 - val_loss: 7.6775
#
# Epoch 00238: val_loss did not improve from 5.31382
# Epoch 239/1000
# 71313/71313 [==============================] - 6s 86us/step - loss: 8.3583 - val_loss: 5.9238
#
# Epoch 00239: val_loss did not improve from 5.31382
# Epoch 240/1000
# 62750/71313 [=========================>....] - ETA: 0s - loss: 8.4374
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-64860ef5b59c> in <module>
#       1 history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=nb_epoch,
#       2           verbose=1, validation_data=(X_val, Y_val),
# ----> 3                      callbacks=[tensorboard,model_check,early_stop])
#
# ~/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/tensorflow3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
dt = datetime.now().replace(second=0, microsecond=0)
model.save_weights('../redes_CNN_R/defs/CNN_regression_R_{}_{}_{}_{}_{}'.format(nb_epoch,batch_size,experimento,algoritmo,dt))

# %%
best_model = load_model(best_model_name)
# best_model = model
score = best_model.evaluate(X_test, Y_test, verbose=0)
print('Test mse:', score)
# print('Test mae:', score[1])
Y_test_predicted=best_model.predict(X_test)
print(Y_test_predicted[:10].flatten())
print(Y_test[:10])

error_prediction=Y_test-Y_test_predicted.flatten()

print(error_prediction[:10])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model error')
plt.ylabel('error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#print(error_prediction)

# %%
n, bins, patches = plt.hist(error_prediction, 400, normed=0, facecolor='green', alpha=0.75)
plt.title("Histogram with 400 bins")
plt.show()
x=bins[:400]
y=n
print(n.shape)
print(bins.shape)
from numpy import exp, loadtxt, pi, sqrt, log

from lmfit import Model
def gaussian(x, amp, cen, wid):
    """1-d gaussian: gaussian(x, amp, cen, wid)"""
    return amp * exp(-((x-cen)/wid)**2 )


gmodel = Model(gaussian)
result = gmodel.fit(y, x=x, amp=1000, cen=0, wid=1)

print(result.fit_report())

plt.plot(x, y, 'bo')
plt.plot(x, result.init_fit, 'k--')
plt.plot(x, result.best_fit, 'r-')
plt.show()

# %%
FWHM=result.params['wid'].value*2*sqrt(log(2))

# %%
print(FWHM)

# %%
Y_test_bin0_predicted=best_model.predict(X_test_bin0)
print(Y_test_bin0_predicted)
error_prediction_bin0=Y_test_bin0-Y_test_bin0_predicted.flatten()
n, bins, patches = plt.hist(error_prediction_bin0, 400, normed=0, facecolor='green', alpha=0.75)

x=bins[:400]
y=n

gmodel = Model(gaussian)
result = gmodel.fit(y, x=x, amp=1000, cen=0, wid=1)
FWHM_bin0=result.params['wid'].value*2*sqrt(log(2))
print(FWHM_bin0)

# %%
Y_test_bin1_predicted=best_model.predict(X_test_bin1)
#print(Y_test_bin1_predicted)
error_prediction_bin1=Y_test_bin1-Y_test_bin1_predicted.flatten()
n, bins, patches = plt.hist(error_prediction_bin1, 400, normed=0, facecolor='green', alpha=0.75)

x=bins[:400]
y=n

gmodel = Model(gaussian)
result = gmodel.fit(y, x=x, amp=1000, cen=0, wid=1)
FWHM_bin1=result.params['wid'].value*2*sqrt(log(2))
print(FWHM_bin1)

# %%
Y_test_bin2_predicted=best_model.predict(X_test_bin2)
#print(Y_test_bin2_predicted)
error_prediction_bin2=Y_test_bin2-Y_test_bin2_predicted.flatten()
n, bins, patches = plt.hist(error_prediction_bin2, 400, normed=0, facecolor='green', alpha=0.75)

x=bins[:400]
y=n

gmodel = Model(gaussian)
result = gmodel.fit(y, x=x, amp=1000, cen=0, wid=1)
FWHM_bin2=result.params['wid'].value*2*sqrt(log(2))
print(FWHM_bin2)

# %%
Y_test_bin3_predicted=best_model.predict(X_test_bin3)
#print(Y_test_bin3_predicted)
error_prediction_bin3=Y_test_bin3-Y_test_bin3_predicted.flatten()
n, bins, patches = plt.hist(error_prediction_bin3, 400, normed=0, facecolor='green', alpha=0.75)

x=bins[:400]
y=n

gmodel = Model(gaussian)
result = gmodel.fit(y, x=x, amp=1000, cen=0, wid=1)
FWHM_bin3=result.params['wid'].value*2*sqrt(log(2))
print(FWHM_bin3)

# %%
Y_test_bin4_predicted=best_model.predict(X_test_bin4)
#print(Y_test_bin4_predicted)
error_prediction_bin4=Y_test_bin4-Y_test_bin4_predicted.flatten()
n, bins, patches = plt.hist(error_prediction_bin4, 400, normed=0, facecolor='green', alpha=0.75)

x=bins[:400]
y=n

gmodel = Model(gaussian)
result = gmodel.fit(y, x=x, amp=1000, cen=0, wid=1)
FWHM_bin4=result.params['wid'].value*2*sqrt(log(2))
print(FWHM_bin4)
print(FWHM_bin3)
print(FWHM_bin2)
print(FWHM_bin1)
print(FWHM_bin0)

# %% [markdown]
# Veamos ahora los histogramnas 2d que nos interesan
